# %% [markdown]
# # Module Five Assignment: Cartpole Problem
# Review the code in this notebook and in the score_logger.py file in the *scores* folder (directory). Once you have reviewed the code, return to this notebook and select **Cell** and then **Run All** from the menu bar to run this code. The code takes several minutes to run.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.9275689688183278, score: 35
# Scores: (min: 35, avg: 35, max: 35)
#
# Run: 2, exploration: 0.8647077305675338, score: 15
# Scores: (min: 15, avg: 25, max: 35)
#
# Run: 3, exploration: 0.7705488893118823, score: 24
# Scores: (min: 15, avg: 24.666666666666668, max: 35)
#
# Run: 4, exploration: 0.7328768546436799, score: 11
# Scores: (min: 11, avg: 21.25, max: 35)
#
# Run: 5, exploration: 0.6498078359349755, score: 25
# Scores: (min: 11, avg: 22, max: 35)
#
# Run: 6, exploration: 0.5761543988830038, score: 25
# Scores: (min: 11, avg: 22.5, max: 35)
#
# Run: 7, exploration: 0.5507399854171277, score: 10
# Scores: (min: 10, avg: 20.714285714285715, max: 35)
#
# Run: 8, exploration: 0.531750826943791, score: 8
# Scores: (min: 8, avg: 19.125, max: 35)
#
# Run: 9, exploration: 0.47622912292284103, score: 23
# Scores: (min: 8, avg: 19.555555555555557, max: 35)
#
# Run: 10, exploration: 0.4417353564707963, score: 16
# Scores: (min: 8, avg: 19.2, max: 35)
#
# Run: 11, exploration: 0.42013897252428334, score: 11
# Scores: (min: 8, avg: 18.454545454545453, max: 35)
#
# Run: 12, exploration: 0.39561243860243744, score: 13
# Scores: (min: 8, avg: 18, max: 35)
#
# Run: 13, exploration: 0.3669578217261671, score: 16
# Scores: (min: 8, avg: 17.846153846153847, max: 35)
#
# Run: 14, exploration: 0.34901730169741024, score: 11
# Scores: (min: 8, avg: 17.357142857142858, max: 35)
#
# Run: 15, exploration: 0.33362200135903064, score: 10
# Scores: (min: 8, avg: 16.866666666666667, max: 35)
#
# Run: 16, exploration: 0.31101247816653554, score: 15
# Scores: (min: 8, avg: 16.75, max: 35)
#
# Run: 17, exploration: 0.2913921604631864, score: 14
# Scores: (min: 8, avg: 16.58823529411765, max: 35)
#
# Run: 18, exploration: 0.27714603575484437, score: 11
# Scores: (min: 8, avg: 16.27777777777778, max: 35)
#
# Run: 19, exploration: 0.2649210072611673, score: 10
# Scores: (min: 8, avg: 15.947368421052632, max: 35)
#
# Run: 20, exploration: 0.2494556624678441, score: 13
# Scores: (min: 8, avg: 15.8, max: 35)
#
# Run: 21, exploration: 0.23965031961336, score: 9
# Scores: (min: 8, avg: 15.476190476190476, max: 35)
#
# Run: 22, exploration: 0.231387331601191, score: 8
# Scores: (min: 8, avg: 15.136363636363637, max: 35)
#
# Run: 23, exploration: 0.2211807388415433, score: 10
# Scores: (min: 8, avg: 14.91304347826087, max: 35)
#
# Run: 24, exploration: 0.20826882814336947, score: 13
# Scores: (min: 8, avg: 14.833333333333334, max: 35)
#
# Run: 25, exploration: 0.19709615934585656, score: 12
# Scores: (min: 8, avg: 14.72, max: 35)
#
# Run: 26, exploration: 0.1903004112552766, score: 8
# Scores: (min: 8, avg: 14.461538461538462, max: 35)
#
# Run: 27, exploration: 0.18190617987607657, score: 10
# Scores: (min: 8, avg: 14.296296296296296, max: 35)
#
# Run: 28, exploration: 0.17388222158237718, score: 10
# Scores: (min: 8, avg: 14.142857142857142, max: 35)
#
# Run: 29, exploration: 0.16538114245489302, score: 11
# Scores: (min: 8, avg: 14.03448275862069, max: 35)
#
# Run: 30, exploration: 0.1572956799768517, score: 11
# Scores: (min: 8, avg: 13.933333333333334, max: 35)
#
# Run: 31, exploration: 0.15035730121053842, score: 10
# Scores: (min: 8, avg: 13.806451612903226, max: 35)
#
# Run: 32, exploration: 0.14300635237083656, score: 11
# Scores: (min: 8, avg: 13.71875, max: 35)
#
# Run: 33, exploration: 0.13669828187021155, score: 10
# Scores: (min: 8, avg: 13.606060606060606, max: 35)
#
# Run: 34, exploration: 0.13066846301911936, score: 10
# Scores: (min: 8, avg: 13.5, max: 35)
#
# Run: 35, exploration: 0.11019338598389174, score: 35
# Scores: (min: 8, avg: 14.114285714285714, max: 35)
#
# Run: 36, exploration: 0.10170090558064004, score: 17
# Scores: (min: 8, avg: 14.194444444444445, max: 35)
#
# Run: 37, exploration: 0.08533607153708872, score: 36
# Scores: (min: 8, avg: 14.783783783783784, max: 36)
#
# Run: 38, exploration: 0.07680992513462537, score: 22
# Scores: (min: 8, avg: 14.973684210526315, max: 36)
#
# Run: 39, exploration: 0.06983222438783, score: 20
# Scores: (min: 8, avg: 15.102564102564102, max: 36)
#
# Run: 40, exploration: 0.062228127537270826, score: 24
# Scores: (min: 8, avg: 15.325, max: 36)
#
# Run: 41, exploration: 0.04916675299948831, score: 48
# Scores: (min: 8, avg: 16.121951219512194, max: 48)
#
# Run: 42, exploration: 0.040032972548509065, score: 42
# Scores: (min: 8, avg: 16.738095238095237, max: 48)
#
# Run: 43, exploration: 0.032433008066058915, score: 43
# Scores: (min: 8, avg: 17.348837209302324, max: 48)
#
# Run: 44, exploration: 0.021937519923982282, score: 79
# Scores: (min: 8, avg: 18.75, max: 79)
#
# Run: 45, exploration: 0.017332943577287888, score: 48
# Scores: (min: 8, avg: 19.4, max: 79)
#
# Run: 46, exploration: 0.015138941243677408, score: 28
# Scores: (min: 8, avg: 19.58695652173913, max: 79)
#
# Run: 47, exploration: 0.012766746905164949, score: 35
# Scores: (min: 8, avg: 19.914893617021278, max: 79)
#
# Run: 48, exploration: 0.010447285872500434, score: 41
# Scores: (min: 8, avg: 20.354166666666668, max: 79)
#
# Run: 49, exploration: 0.01, score: 83
# Scores: (min: 8, avg: 21.632653061224488, max: 83)
#
# Run: 50, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 21.88, max: 83)
#
# Run: 51, exploration: 0.01, score: 49
# Scores: (min: 8, avg: 22.41176470588235, max: 83)
#
# Run: 52, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 22.903846153846153, max: 83)
#
# Run: 53, exploration: 0.01, score: 139
# Scores: (min: 8, avg: 25.09433962264151, max: 139)
#
# Run: 54, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 25.37037037037037, max: 139)
#
# Run: 55, exploration: 0.01, score: 72
# Scores: (min: 8, avg: 26.21818181818182, max: 139)
#
# Run: 56, exploration: 0.01, score: 84
# Scores: (min: 8, avg: 27.25, max: 139)
#
# Run: 57, exploration: 0.01, score: 56
# Scores: (min: 8, avg: 27.75438596491228, max: 139)
#
# Run: 58, exploration: 0.01, score: 87
# Scores: (min: 8, avg: 28.775862068965516, max: 139)
#
# Run: 59, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 29.93220338983051, max: 139)
#
# Run: 60, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 31.883333333333333, max: 147)
#
# Run: 61, exploration: 0.01, score: 208
# Scores: (min: 8, avg: 34.77049180327869, max: 208)
#
# Run: 62, exploration: 0.01, score: 90
# Scores: (min: 8, avg: 35.66129032258065, max: 208)
#
# Run: 63, exploration: 0.01, score: 130
# Scores: (min: 8, avg: 37.15873015873016, max: 208)
#
# Run: 64, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 38.9375, max: 208)
#
# Run: 65, exploration: 0.01, score: 223
# Scores: (min: 8, avg: 41.76923076923077, max: 223)
#
# Run: 66, exploration: 0.01, score: 213
# Scores: (min: 8, avg: 44.36363636363637, max: 223)
#
# Run: 67, exploration: 0.01, score: 214
# Scores: (min: 8, avg: 46.8955223880597, max: 223)
#
# Run: 68, exploration: 0.01, score: 244
# Scores: (min: 8, avg: 49.794117647058826, max: 244)
#
# Run: 69, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 51.7536231884058, max: 244)
#
# Run: 70, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 53.92857142857143, max: 244)
#
# Run: 71, exploration: 0.01, score: 206
# Scores: (min: 8, avg: 56.070422535211264, max: 244)
#
# Run: 72, exploration: 0.01, score: 251
# Scores: (min: 8, avg: 58.77777777777778, max: 251)
#
# Run: 73, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 60.87671232876713, max: 251)
#
# Run: 74, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 62.554054054054056, max: 251)
#
# Run: 75, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 64.62666666666667, max: 251)
#
# Run: 76, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 66.39473684210526, max: 251)
#
# Run: 77, exploration: 0.01, score: 176
# Scores: (min: 8, avg: 67.81818181818181, max: 251)
#
# Run: 78, exploration: 0.01, score: 227
# Scores: (min: 8, avg: 69.85897435897436, max: 251)
#
# Run: 79, exploration: 0.01, score: 208
# Scores: (min: 8, avg: 71.60759493670886, max: 251)
#
# Run: 80, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 73.325, max: 251)
#
# Run: 81, exploration: 0.01, score: 209
# Scores: (min: 8, avg: 75, max: 251)
#
# Run: 82, exploration: 0.01, score: 205
# Scores: (min: 8, avg: 76.58536585365853, max: 251)
#
# Run: 83, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 77.75903614457832, max: 251)
#
# Run: 84, exploration: 0.01, score: 213
# Scores: (min: 8, avg: 79.36904761904762, max: 251)
#
# Run: 85, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 80.55294117647058, max: 251)
#
# Run: 86, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 81.87209302325581, max: 251)
#
# Run: 87, exploration: 0.01, score: 184
# Scores: (min: 8, avg: 83.04597701149426, max: 251)
#
# Run: 88, exploration: 0.01, score: 236
# Scores: (min: 8, avg: 84.7840909090909, max: 251)
#
# Run: 89, exploration: 0.01, score: 208
# Scores: (min: 8, avg: 86.1685393258427, max: 251)
#
# Run: 90, exploration: 0.01, score: 205
# Scores: (min: 8, avg: 87.4888888888889, max: 251)
#
# Run: 91, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 88.50549450549451, max: 251)
#
# Run: 92, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 89.46739130434783, max: 251)
#
# Run: 93, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 90.64516129032258, max: 251)
#
# Run: 94, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 91.6063829787234, max: 251)
#
# Run: 95, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 92.6, max: 251)
#
# Run: 96, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 93.35416666666667, max: 251)
#
# Run: 97, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 94.61855670103093, max: 251)
#
# Run: 98, exploration: 0.01, score: 224
# Scores: (min: 8, avg: 95.93877551020408, max: 251)
#
# Run: 99, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 96.81818181818181, max: 251)
#
# Run: 100, exploration: 0.01, score: 202
# Scores: (min: 8, avg: 97.87, max: 251)
#
# Run: 101, exploration: 0.01, score: 216
# Scores: (min: 8, avg: 99.68, max: 251)
#
# Run: 102, exploration: 0.01, score: 226
# Scores: (min: 8, avg: 101.79, max: 251)
#
# Run: 103, exploration: 0.01, score: 189
# Scores: (min: 8, avg: 103.44, max: 251)
#
# Run: 104, exploration: 0.01, score: 186
# Scores: (min: 8, avg: 105.19, max: 251)
#
# Run: 105, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 106.75, max: 251)
#
# Run: 106, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 108.47, max: 251)
#
# Run: 107, exploration: 0.01, score: 396
# Scores: (min: 8, avg: 112.33, max: 396)
#
# Run: 108, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 113.96, max: 396)
#
# Run: 109, exploration: 0.01, score: 206
# Scores: (min: 8, avg: 115.79, max: 396)
#
# Run: 110, exploration: 0.01, score: 245
# Scores: (min: 8, avg: 118.08, max: 396)
#
# Run: 111, exploration: 0.01, score: 220
# Scores: (min: 8, avg: 120.17, max: 396)
#
# Run: 112, exploration: 0.01, score: 349
# Scores: (min: 8, avg: 123.53, max: 396)
#
# Run: 113, exploration: 0.01, score: 221
# Scores: (min: 8, avg: 125.58, max: 396)
#
# Run: 114, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 127.24, max: 396)
#
# Run: 115, exploration: 0.01, score: 270
# Scores: (min: 8, avg: 129.84, max: 396)
#
# Run: 116, exploration: 0.01, score: 188
# Scores: (min: 8, avg: 131.57, max: 396)
#
# Run: 117, exploration: 0.01, score: 203
# Scores: (min: 8, avg: 133.46, max: 396)
#
# Run: 118, exploration: 0.01, score: 200
# Scores: (min: 8, avg: 135.35, max: 396)
#
# Run: 119, exploration: 0.01, score: 235
# Scores: (min: 8, avg: 137.6, max: 396)
#
# Run: 120, exploration: 0.01, score: 173
# Scores: (min: 8, avg: 139.2, max: 396)
#
# Run: 121, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 140.71, max: 396)
#
# Run: 122, exploration: 0.01, score: 193
# Scores: (min: 8, avg: 142.56, max: 396)
#
# Run: 123, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 144.2, max: 396)
#
# Run: 124, exploration: 0.01, score: 252
# Scores: (min: 8, avg: 146.59, max: 396)
#
# Run: 125, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 148.41, max: 396)
#
# Run: 126, exploration: 0.01, score: 179
# Scores: (min: 10, avg: 150.12, max: 396)
#
# Run: 127, exploration: 0.01, score: 180
# Scores: (min: 10, avg: 151.82, max: 396)
#
# Run: 128, exploration: 0.01, score: 236
# Scores: (min: 10, avg: 154.08, max: 396)
#
# Run: 129, exploration: 0.01, score: 175
# Scores: (min: 10, avg: 155.72, max: 396)
#
# Run: 130, exploration: 0.01, score: 172
# Scores: (min: 10, avg: 157.33, max: 396)
#
# Run: 131, exploration: 0.01, score: 178
# Scores: (min: 10, avg: 159.01, max: 396)
#
# Run: 132, exploration: 0.01, score: 191
# Scores: (min: 10, avg: 160.81, max: 396)
#
# Run: 133, exploration: 0.01, score: 173
# Scores: (min: 10, avg: 162.44, max: 396)
#
# Run: 134, exploration: 0.01, score: 193
# Scores: (min: 17, avg: 164.27, max: 396)
#
# Run: 135, exploration: 0.01, score: 241
# Scores: (min: 17, avg: 166.33, max: 396)
#
# Run: 136, exploration: 0.01, score: 179
# Scores: (min: 20, avg: 167.95, max: 396)
#
# Run: 137, exploration: 0.01, score: 179
# Scores: (min: 20, avg: 169.38, max: 396)
#
# Run: 138, exploration: 0.01, score: 198
# Scores: (min: 20, avg: 171.14, max: 396)
#
# Run: 139, exploration: 0.01, score: 325
# Scores: (min: 24, avg: 174.19, max: 396)
#
# Run: 140, exploration: 0.01, score: 182
# Scores: (min: 28, avg: 175.77, max: 396)
#
# Run: 141, exploration: 0.01, score: 211
# Scores: (min: 28, avg: 177.4, max: 396)
#
# Run: 142, exploration: 0.01, score: 201
# Scores: (min: 28, avg: 178.99, max: 396)
#
# Run: 143, exploration: 0.01, score: 216
# Scores: (min: 28, avg: 180.72, max: 396)
#
# Run: 144, exploration: 0.01, score: 254
# Scores: (min: 28, avg: 182.47, max: 396)
#
# Run: 145, exploration: 0.01, score: 177
# Scores: (min: 28, avg: 183.76, max: 396)
#
# Run: 146, exploration: 0.01, score: 209
# Scores: (min: 34, avg: 185.57, max: 396)
#
# Run: 147, exploration: 0.01, score: 175
# Scores: (min: 34, avg: 186.97, max: 396)
#
# Run: 148, exploration: 0.01, score: 165
# Scores: (min: 34, avg: 188.21, max: 396)
#
# Run: 149, exploration: 0.01, score: 232
# Scores: (min: 34, avg: 189.7, max: 396)
#
# Run: 150, exploration: 0.01, score: 267
# Scores: (min: 40, avg: 192.03, max: 396)
#
# Run: 151, exploration: 0.01, score: 223
# Scores: (min: 40, avg: 193.77, max: 396)
#
# Run: 152, exploration: 0.01, score: 195
# Scores: (min: 40, avg: 195.24, max: 396)
#
# Solved in 52 runs, 152 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
# modifying Discount factor/GAMMA
# original = 0.95
# experiment = 0.75 
# I stopped the program at 278 Runs and 30 minutes.
# Previously stopped at 1500 total runs.
# No solution found.

ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.75  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

cartpole()
# Out:
# Run: 1, exploration: 0.985074875, score: 23
# Scores: (min: 23, avg: 23, max: 23)
#
# Run: 2, exploration: 0.8911090557802088, score: 21
# Scores: (min: 21, avg: 22, max: 23)
#
# Run: 3, exploration: 0.8390886103705794, score: 13
# Scores: (min: 13, avg: 19, max: 23)
#
# Run: 4, exploration: 0.7901049725470279, score: 13
# Scores: (min: 13, avg: 17.5, max: 23)
#
# Run: 5, exploration: 0.7111635524897149, score: 22
# Scores: (min: 13, avg: 18.4, max: 23)
#
# Run: 6, exploration: 0.6118738784280476, score: 31
# Scores: (min: 13, avg: 20.5, max: 31)
#
# Run: 7, exploration: 0.5618938591163328, score: 18
# Scores: (min: 13, avg: 20.142857142857142, max: 31)
#
# Run: 8, exploration: 0.5057535983897912, score: 22
# Scores: (min: 13, avg: 20.375, max: 31)
#
# Run: 9, exploration: 0.47147873742168567, score: 15
# Scores: (min: 13, avg: 19.77777777777778, max: 31)
#
# Run: 10, exploration: 0.3706551064126331, score: 49
# Scores: (min: 13, avg: 22.7, max: 49)
#
# Run: 11, exploration: 0.26759021970270175, score: 66
# Scores: (min: 13, avg: 26.636363636363637, max: 66)
#
# Run: 12, exploration: 0.10692863247165257, score: 184
# Scores: (min: 13, avg: 39.75, max: 184)
#
# Run: 13, exploration: 0.058595424120670696, score: 121
# Scores: (min: 13, avg: 46, max: 184)
#
# Run: 14, exploration: 0.033423255248208356, score: 113
# Scores: (min: 13, avg: 50.785714285714285, max: 184)
#
# Run: 15, exploration: 0.01964695745288379, score: 107
# Scores: (min: 13, avg: 54.53333333333333, max: 184)
#
# Run: 16, exploration: 0.01, score: 469
# Scores: (min: 13, avg: 80.4375, max: 469)
#
# Run: 17, exploration: 0.01, score: 386
# Scores: (min: 13, avg: 98.41176470588235, max: 469)
#
# Run: 18, exploration: 0.01, score: 372
# Scores: (min: 13, avg: 113.61111111111111, max: 469)
#
# Run: 19, exploration: 0.01, score: 234
# Scores: (min: 13, avg: 119.94736842105263, max: 469)
#
# Run: 20, exploration: 0.01, score: 166
# Scores: (min: 13, avg: 122.25, max: 469)
#
# Run: 21, exploration: 0.01, score: 211
# Scores: (min: 13, avg: 126.47619047619048, max: 469)
#
# Run: 22, exploration: 0.01, score: 98
# Scores: (min: 13, avg: 125.18181818181819, max: 469)
#
# Run: 23, exploration: 0.01, score: 456
# Scores: (min: 13, avg: 139.56521739130434, max: 469)
#
# Run: 24, exploration: 0.01, score: 207
# Scores: (min: 13, avg: 142.375, max: 469)
#
# Run: 25, exploration: 0.01, score: 308
# Scores: (min: 13, avg: 149, max: 469)
#
# Run: 26, exploration: 0.01, score: 211
# Scores: (min: 13, avg: 151.3846153846154, max: 469)
#
# Run: 27, exploration: 0.01, score: 167
# Scores: (min: 13, avg: 151.96296296296296, max: 469)
#
# Run: 28, exploration: 0.01, score: 204
# Scores: (min: 13, avg: 153.82142857142858, max: 469)
#
# Run: 29, exploration: 0.01, score: 399
# Scores: (min: 13, avg: 162.27586206896552, max: 469)
#
# Run: 30, exploration: 0.01, score: 345
# Scores: (min: 13, avg: 168.36666666666667, max: 469)
#
# Run: 31, exploration: 0.01, score: 372
# Scores: (min: 13, avg: 174.93548387096774, max: 469)
#
# Run: 32, exploration: 0.01, score: 353
# Scores: (min: 13, avg: 180.5, max: 469)
#
# Run: 33, exploration: 0.01, score: 142
# Scores: (min: 13, avg: 179.33333333333334, max: 469)
#
# Run: 34, exploration: 0.01, score: 194
# Scores: (min: 13, avg: 179.76470588235293, max: 469)
#
# Run: 35, exploration: 0.01, score: 164
# Scores: (min: 13, avg: 179.31428571428572, max: 469)
#
# Run: 36, exploration: 0.01, score: 193
# Scores: (min: 13, avg: 179.69444444444446, max: 469)
#
# Run: 37, exploration: 0.01, score: 191
# Scores: (min: 13, avg: 180, max: 469)
#
# Run: 38, exploration: 0.01, score: 304
# Scores: (min: 13, avg: 183.26315789473685, max: 469)
#
# Run: 39, exploration: 0.01, score: 175
# Scores: (min: 13, avg: 183.05128205128204, max: 469)
#
# Run: 40, exploration: 0.01, score: 211
# Scores: (min: 13, avg: 183.75, max: 469)
#
# Run: 41, exploration: 0.01, score: 335
# Scores: (min: 13, avg: 187.4390243902439, max: 469)
#
# Run: 42, exploration: 0.01, score: 114
# Scores: (min: 13, avg: 185.6904761904762, max: 469)
#
# Run: 43, exploration: 0.01, score: 162
# Scores: (min: 13, avg: 185.13953488372093, max: 469)
#
# Run: 44, exploration: 0.01, score: 194
# Scores: (min: 13, avg: 185.3409090909091, max: 469)
#
# Run: 45, exploration: 0.01, score: 100
# Scores: (min: 13, avg: 183.44444444444446, max: 469)
#
# Run: 46, exploration: 0.01, score: 260
# Scores: (min: 13, avg: 185.1086956521739, max: 469)
#
# Run: 47, exploration: 0.01, score: 195
# Scores: (min: 13, avg: 185.31914893617022, max: 469)
#
# Run: 48, exploration: 0.01, score: 117
# Scores: (min: 13, avg: 183.89583333333334, max: 469)
#
# Run: 49, exploration: 0.01, score: 204
# Scores: (min: 13, avg: 184.30612244897958, max: 469)
#
# Run: 50, exploration: 0.01, score: 299
# Scores: (min: 13, avg: 186.6, max: 469)
#
# Run: 51, exploration: 0.01, score: 124
# Scores: (min: 13, avg: 185.37254901960785, max: 469)
#
# Run: 52, exploration: 0.01, score: 236
# Scores: (min: 13, avg: 186.34615384615384, max: 469)
#
# Run: 53, exploration: 0.01, score: 221
# Scores: (min: 13, avg: 187, max: 469)
#
# Run: 54, exploration: 0.01, score: 212
# Scores: (min: 13, avg: 187.46296296296296, max: 469)
#
# Run: 55, exploration: 0.01, score: 57
# Scores: (min: 13, avg: 185.0909090909091, max: 469)
#
# Run: 56, exploration: 0.01, score: 91
# Scores: (min: 13, avg: 183.41071428571428, max: 469)
#
# Run: 57, exploration: 0.01, score: 100
# Scores: (min: 13, avg: 181.94736842105263, max: 469)
#
# Run: 58, exploration: 0.01, score: 78
# Scores: (min: 13, avg: 180.1551724137931, max: 469)
#
# Run: 59, exploration: 0.01, score: 148
# Scores: (min: 13, avg: 179.61016949152543, max: 469)
#
# Run: 60, exploration: 0.01, score: 112
# Scores: (min: 13, avg: 178.48333333333332, max: 469)
#
# Run: 61, exploration: 0.01, score: 189
# Scores: (min: 13, avg: 178.65573770491804, max: 469)
#
# Run: 62, exploration: 0.01, score: 86
# Scores: (min: 13, avg: 177.16129032258064, max: 469)
#
# Run: 63, exploration: 0.01, score: 207
# Scores: (min: 13, avg: 177.63492063492063, max: 469)
#
# Run: 64, exploration: 0.01, score: 72
# Scores: (min: 13, avg: 175.984375, max: 469)
#
# Run: 65, exploration: 0.01, score: 60
# Scores: (min: 13, avg: 174.2, max: 469)
#
# Run: 66, exploration: 0.01, score: 102
# Scores: (min: 13, avg: 173.1060606060606, max: 469)
#
# Run: 67, exploration: 0.01, score: 441
# Scores: (min: 13, avg: 177.1044776119403, max: 469)
#
# Run: 68, exploration: 0.01, score: 135
# Scores: (min: 13, avg: 176.48529411764707, max: 469)
#
# Run: 69, exploration: 0.01, score: 147
# Scores: (min: 13, avg: 176.05797101449275, max: 469)
#
# Run: 70, exploration: 0.01, score: 500
# Scores: (min: 13, avg: 180.68571428571428, max: 500)
#
# Run: 71, exploration: 0.01, score: 266
# Scores: (min: 13, avg: 181.88732394366198, max: 500)
#
# Run: 72, exploration: 0.01, score: 109
# Scores: (min: 13, avg: 180.875, max: 500)
#
# Run: 73, exploration: 0.01, score: 49
# Scores: (min: 13, avg: 179.06849315068493, max: 500)
#
# Run: 74, exploration: 0.01, score: 40
# Scores: (min: 13, avg: 177.1891891891892, max: 500)
#
# Run: 75, exploration: 0.01, score: 166
# Scores: (min: 13, avg: 177.04, max: 500)
#
# Run: 76, exploration: 0.01, score: 94
# Scores: (min: 13, avg: 175.94736842105263, max: 500)
#
# Run: 77, exploration: 0.01, score: 144
# Scores: (min: 13, avg: 175.53246753246754, max: 500)
#
# Run: 78, exploration: 0.01, score: 139
# Scores: (min: 13, avg: 175.06410256410257, max: 500)
#
# Run: 79, exploration: 0.01, score: 92
# Scores: (min: 13, avg: 174.0126582278481, max: 500)
#
# Run: 80, exploration: 0.01, score: 82
# Scores: (min: 13, avg: 172.8625, max: 500)
#
# Run: 81, exploration: 0.01, score: 35
# Scores: (min: 13, avg: 171.1604938271605, max: 500)
#
# Run: 82, exploration: 0.01, score: 138
# Scores: (min: 13, avg: 170.7560975609756, max: 500)
#
# Run: 83, exploration: 0.01, score: 101
# Scores: (min: 13, avg: 169.9156626506024, max: 500)
#
# Run: 84, exploration: 0.01, score: 102
# Scores: (min: 13, avg: 169.10714285714286, max: 500)
#
# Run: 85, exploration: 0.01, score: 162
# Scores: (min: 13, avg: 169.0235294117647, max: 500)
#
# Run: 86, exploration: 0.01, score: 103
# Scores: (min: 13, avg: 168.25581395348837, max: 500)
#
# Run: 87, exploration: 0.01, score: 135
# Scores: (min: 13, avg: 167.8735632183908, max: 500)
#
# Run: 88, exploration: 0.01, score: 66
# Scores: (min: 13, avg: 166.7159090909091, max: 500)
#
# Run: 89, exploration: 0.01, score: 36
# Scores: (min: 13, avg: 165.24719101123594, max: 500)
#
# Run: 90, exploration: 0.01, score: 91
# Scores: (min: 13, avg: 164.42222222222222, max: 500)
#
# Run: 91, exploration: 0.01, score: 140
# Scores: (min: 13, avg: 164.15384615384616, max: 500)
#
# Run: 92, exploration: 0.01, score: 94
# Scores: (min: 13, avg: 163.3913043478261, max: 500)
#
# Run: 93, exploration: 0.01, score: 191
# Scores: (min: 13, avg: 163.68817204301075, max: 500)
#
# Run: 94, exploration: 0.01, score: 205
# Scores: (min: 13, avg: 164.12765957446808, max: 500)
#
# Run: 95, exploration: 0.01, score: 129
# Scores: (min: 13, avg: 163.7578947368421, max: 500)
#
# Run: 96, exploration: 0.01, score: 118
# Scores: (min: 13, avg: 163.28125, max: 500)
#
# Run: 97, exploration: 0.01, score: 113
# Scores: (min: 13, avg: 162.76288659793815, max: 500)
#
# Run: 98, exploration: 0.01, score: 71
# Scores: (min: 13, avg: 161.8265306122449, max: 500)
#
# Run: 99, exploration: 0.01, score: 12
# Scores: (min: 12, avg: 160.31313131313132, max: 500)
#
# Run: 100, exploration: 0.01, score: 124
# Scores: (min: 12, avg: 159.95, max: 500)
#
# Run: 101, exploration: 0.01, score: 153
# Scores: (min: 12, avg: 161.25, max: 500)
#
# Run: 102, exploration: 0.01, score: 245
# Scores: (min: 12, avg: 163.49, max: 500)
#
# Run: 103, exploration: 0.01, score: 98
# Scores: (min: 12, avg: 164.34, max: 500)
#
# Run: 104, exploration: 0.01, score: 26
# Scores: (min: 12, avg: 164.47, max: 500)
#
# Run: 105, exploration: 0.01, score: 47
# Scores: (min: 12, avg: 164.72, max: 500)
#
# Run: 106, exploration: 0.01, score: 62
# Scores: (min: 12, avg: 165.03, max: 500)
#
# Run: 107, exploration: 0.01, score: 192
# Scores: (min: 12, avg: 166.77, max: 500)
#
# Run: 108, exploration: 0.01, score: 39
# Scores: (min: 12, avg: 166.94, max: 500)
#
# Run: 109, exploration: 0.01, score: 94
# Scores: (min: 12, avg: 167.73, max: 500)
#
# Run: 110, exploration: 0.01, score: 25
# Scores: (min: 12, avg: 167.49, max: 500)
#
# Run: 111, exploration: 0.01, score: 37
# Scores: (min: 12, avg: 167.2, max: 500)
#
# Run: 112, exploration: 0.01, score: 169
# Scores: (min: 12, avg: 167.05, max: 500)
#
# Run: 113, exploration: 0.01, score: 126
# Scores: (min: 12, avg: 167.1, max: 500)
#
# Run: 114, exploration: 0.01, score: 50
# Scores: (min: 12, avg: 166.47, max: 500)
#
# Run: 115, exploration: 0.01, score: 38
# Scores: (min: 12, avg: 165.78, max: 500)
#
# Run: 116, exploration: 0.01, score: 143
# Scores: (min: 12, avg: 162.52, max: 500)
#
# Run: 117, exploration: 0.01, score: 97
# Scores: (min: 12, avg: 159.63, max: 500)
#
# Run: 118, exploration: 0.01, score: 25
# Scores: (min: 12, avg: 156.16, max: 500)
#
# Run: 119, exploration: 0.01, score: 15
# Scores: (min: 12, avg: 153.97, max: 500)
#
# Run: 120, exploration: 0.01, score: 428
# Scores: (min: 12, avg: 156.59, max: 500)
#
# Run: 121, exploration: 0.01, score: 71
# Scores: (min: 12, avg: 155.19, max: 500)
#
# Run: 122, exploration: 0.01, score: 219
# Scores: (min: 12, avg: 156.4, max: 500)
#
# Run: 123, exploration: 0.01, score: 323
# Scores: (min: 12, avg: 155.07, max: 500)
#
# Run: 124, exploration: 0.01, score: 119
# Scores: (min: 12, avg: 154.19, max: 500)
#
# Run: 125, exploration: 0.01, score: 367
# Scores: (min: 12, avg: 154.78, max: 500)
#
# Run: 126, exploration: 0.01, score: 157
# Scores: (min: 12, avg: 154.24, max: 500)
#
# Run: 127, exploration: 0.01, score: 103
# Scores: (min: 12, avg: 153.6, max: 500)
#
# Run: 128, exploration: 0.01, score: 137
# Scores: (min: 12, avg: 152.93, max: 500)
#
# Run: 129, exploration: 0.01, score: 107
# Scores: (min: 12, avg: 150.01, max: 500)
#
# Run: 130, exploration: 0.01, score: 63
# Scores: (min: 12, avg: 147.19, max: 500)
#
# Run: 131, exploration: 0.01, score: 84
# Scores: (min: 12, avg: 144.31, max: 500)
#
# Run: 132, exploration: 0.01, score: 71
# Scores: (min: 12, avg: 141.49, max: 500)
#
# Run: 133, exploration: 0.01, score: 180
# Scores: (min: 12, avg: 141.87, max: 500)
#
# Run: 134, exploration: 0.01, score: 54
# Scores: (min: 12, avg: 140.47, max: 500)
#
# Run: 135, exploration: 0.01, score: 76
# Scores: (min: 12, avg: 139.59, max: 500)
#
# Run: 136, exploration: 0.01, score: 196
# Scores: (min: 12, avg: 139.62, max: 500)
#
# Run: 137, exploration: 0.01, score: 46
# Scores: (min: 12, avg: 138.17, max: 500)
#
# Run: 138, exploration: 0.01, score: 53
# Scores: (min: 12, avg: 135.66, max: 500)
#
# Run: 139, exploration: 0.01, score: 173
# Scores: (min: 12, avg: 135.64, max: 500)
#
# Run: 140, exploration: 0.01, score: 184
# Scores: (min: 12, avg: 135.37, max: 500)
#
# Run: 141, exploration: 0.01, score: 57
# Scores: (min: 12, avg: 132.59, max: 500)
#
# Run: 142, exploration: 0.01, score: 134
# Scores: (min: 12, avg: 132.79, max: 500)
#
# Run: 143, exploration: 0.01, score: 111
# Scores: (min: 12, avg: 132.28, max: 500)
#
# Run: 144, exploration: 0.01, score: 288
# Scores: (min: 12, avg: 133.22, max: 500)
#
# Run: 145, exploration: 0.01, score: 246
# Scores: (min: 12, avg: 134.68, max: 500)
#
# Run: 146, exploration: 0.01, score: 433
# Scores: (min: 12, avg: 136.41, max: 500)
#
# Run: 147, exploration: 0.01, score: 39
# Scores: (min: 12, avg: 134.85, max: 500)
#
# Run: 148, exploration: 0.01, score: 26
# Scores: (min: 12, avg: 133.94, max: 500)
#
# Run: 149, exploration: 0.01, score: 91
# Scores: (min: 12, avg: 132.81, max: 500)
#
# Run: 150, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 130.98, max: 500)
#
# Run: 151, exploration: 0.01, score: 87
# Scores: (min: 12, avg: 130.61, max: 500)
#
# Run: 152, exploration: 0.01, score: 70
# Scores: (min: 12, avg: 128.95, max: 500)
#
# Run: 153, exploration: 0.01, score: 220
# Scores: (min: 12, avg: 128.94, max: 500)
#
# Run: 154, exploration: 0.01, score: 137
# Scores: (min: 12, avg: 128.19, max: 500)
#
# Run: 155, exploration: 0.01, score: 130
# Scores: (min: 12, avg: 128.92, max: 500)
#
# Run: 156, exploration: 0.01, score: 320
# Scores: (min: 12, avg: 131.21, max: 500)
#
# Run: 157, exploration: 0.01, score: 76
# Scores: (min: 12, avg: 130.97, max: 500)
#
# Run: 158, exploration: 0.01, score: 30
# Scores: (min: 12, avg: 130.49, max: 500)
#
# Run: 159, exploration: 0.01, score: 46
# Scores: (min: 12, avg: 129.47, max: 500)
#
# Run: 160, exploration: 0.01, score: 117
# Scores: (min: 12, avg: 129.52, max: 500)
#
# Run: 161, exploration: 0.01, score: 123
# Scores: (min: 12, avg: 128.86, max: 500)
#
# Run: 162, exploration: 0.01, score: 46
# Scores: (min: 12, avg: 128.46, max: 500)
#
# Run: 163, exploration: 0.01, score: 63
# Scores: (min: 12, avg: 127.02, max: 500)
#
# Run: 164, exploration: 0.01, score: 79
# Scores: (min: 12, avg: 127.09, max: 500)
#
# Run: 165, exploration: 0.01, score: 207
# Scores: (min: 12, avg: 128.56, max: 500)
#
# Run: 166, exploration: 0.01, score: 115
# Scores: (min: 12, avg: 128.69, max: 500)
#
# Run: 167, exploration: 0.01, score: 177
# Scores: (min: 12, avg: 126.05, max: 500)
#
# Run: 168, exploration: 0.01, score: 144
# Scores: (min: 12, avg: 126.14, max: 500)
#
# Run: 169, exploration: 0.01, score: 74
# Scores: (min: 12, avg: 125.41, max: 500)
#
# Run: 170, exploration: 0.01, score: 43
# Scores: (min: 12, avg: 120.84, max: 433)
#
# Run: 171, exploration: 0.01, score: 37
# Scores: (min: 12, avg: 118.55, max: 433)
#
# Run: 172, exploration: 0.01, score: 15
# Scores: (min: 12, avg: 117.61, max: 433)
#
# Run: 173, exploration: 0.01, score: 45
# Scores: (min: 12, avg: 117.57, max: 433)
#
# Run: 174, exploration: 0.01, score: 299
# Scores: (min: 12, avg: 120.16, max: 433)
#
# Run: 175, exploration: 0.01, score: 45
# Scores: (min: 12, avg: 118.95, max: 433)
#
# Run: 176, exploration: 0.01, score: 11
# Scores: (min: 11, avg: 118.12, max: 433)
#
# Run: 177, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 116.8, max: 433)
#
# Run: 178, exploration: 0.01, score: 31
# Scores: (min: 11, avg: 115.72, max: 433)
#
# Run: 179, exploration: 0.01, score: 128
# Scores: (min: 11, avg: 116.08, max: 433)
#
# Run: 180, exploration: 0.01, score: 159
# Scores: (min: 11, avg: 116.85, max: 433)
#
# Run: 181, exploration: 0.01, score: 18
# Scores: (min: 11, avg: 116.68, max: 433)
#
# Run: 182, exploration: 0.01, score: 100
# Scores: (min: 11, avg: 116.3, max: 433)
#
# Run: 183, exploration: 0.01, score: 21
# Scores: (min: 11, avg: 115.5, max: 433)
#
# Run: 184, exploration: 0.01, score: 308
# Scores: (min: 11, avg: 117.56, max: 433)
#
# Run: 185, exploration: 0.01, score: 95
# Scores: (min: 11, avg: 116.89, max: 433)
#
# Run: 186, exploration: 0.01, score: 112
# Scores: (min: 11, avg: 116.98, max: 433)
#
# Run: 187, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 117.08, max: 433)
#
# Run: 188, exploration: 0.01, score: 112
# Scores: (min: 11, avg: 117.54, max: 433)
#
# Run: 189, exploration: 0.01, score: 62
# Scores: (min: 11, avg: 117.8, max: 433)
#
# Run: 190, exploration: 0.01, score: 97
# Scores: (min: 11, avg: 117.86, max: 433)
#
# Run: 191, exploration: 0.01, score: 210
# Scores: (min: 11, avg: 118.56, max: 433)
#
# Run: 192, exploration: 0.01, score: 69
# Scores: (min: 11, avg: 118.31, max: 433)
#
# Run: 193, exploration: 0.01, score: 98
# Scores: (min: 11, avg: 117.38, max: 433)
#
# Run: 194, exploration: 0.01, score: 204
# Scores: (min: 11, avg: 117.37, max: 433)
#
# Run: 195, exploration: 0.01, score: 132
# Scores: (min: 11, avg: 117.4, max: 433)
#
# Run: 196, exploration: 0.01, score: 383
# Scores: (min: 11, avg: 120.05, max: 433)
#
# Run: 197, exploration: 0.01, score: 311
# Scores: (min: 11, avg: 122.03, max: 433)
#
# Run: 198, exploration: 0.01, score: 101
# Scores: (min: 11, avg: 122.33, max: 433)
#
# Run: 199, exploration: 0.01, score: 140
# Scores: (min: 11, avg: 123.61, max: 433)
#
# Run: 200, exploration: 0.01, score: 167
# Scores: (min: 11, avg: 124.04, max: 433)
#
# Run: 201, exploration: 0.01, score: 132
# Scores: (min: 11, avg: 123.83, max: 433)
#
# Run: 202, exploration: 0.01, score: 371
# Scores: (min: 11, avg: 125.09, max: 433)
#
# Run: 203, exploration: 0.01, score: 121
# Scores: (min: 11, avg: 125.32, max: 433)
#
# Run: 204, exploration: 0.01, score: 144
# Scores: (min: 11, avg: 126.5, max: 433)
#
# Run: 205, exploration: 0.01, score: 114
# Scores: (min: 11, avg: 127.17, max: 433)
#
# Run: 206, exploration: 0.01, score: 101
# Scores: (min: 11, avg: 127.56, max: 433)
#
# Run: 207, exploration: 0.01, score: 77
# Scores: (min: 11, avg: 126.41, max: 433)
#
# Run: 208, exploration: 0.01, score: 58
# Scores: (min: 11, avg: 126.6, max: 433)
#
# Run: 209, exploration: 0.01, score: 160
# Scores: (min: 11, avg: 127.26, max: 433)
#
# Run: 210, exploration: 0.01, score: 146
# Scores: (min: 11, avg: 128.47, max: 433)
#
# Run: 211, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 129.46, max: 433)
#
# Run: 212, exploration: 0.01, score: 81
# Scores: (min: 11, avg: 128.58, max: 433)
#
# Run: 213, exploration: 0.01, score: 193
# Scores: (min: 11, avg: 129.25, max: 433)
#
# Run: 214, exploration: 0.01, score: 309
# Scores: (min: 11, avg: 131.84, max: 433)
#
# Run: 215, exploration: 0.01, score: 204
# Scores: (min: 11, avg: 133.5, max: 433)
#
# Run: 216, exploration: 0.01, score: 110
# Scores: (min: 11, avg: 133.17, max: 433)
#
# Run: 217, exploration: 0.01, score: 165
# Scores: (min: 11, avg: 133.85, max: 433)
#
# Run: 218, exploration: 0.01, score: 77
# Scores: (min: 11, avg: 134.37, max: 433)
#
# Run: 219, exploration: 0.01, score: 174
# Scores: (min: 11, avg: 135.96, max: 433)
#
# Run: 220, exploration: 0.01, score: 76
# Scores: (min: 11, avg: 132.44, max: 433)
#
# Run: 221, exploration: 0.01, score: 89
# Scores: (min: 11, avg: 132.62, max: 433)
#
# Run: 222, exploration: 0.01, score: 108
# Scores: (min: 11, avg: 131.51, max: 433)
#
# Run: 223, exploration: 0.01, score: 36
# Scores: (min: 11, avg: 128.64, max: 433)
#
# Run: 224, exploration: 0.01, score: 237
# Scores: (min: 11, avg: 129.82, max: 433)
#
# Run: 225, exploration: 0.01, score: 114
# Scores: (min: 11, avg: 127.29, max: 433)
#
# Run: 226, exploration: 0.01, score: 88
# Scores: (min: 11, avg: 126.6, max: 433)
#
# Run: 227, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 126.8, max: 433)
#
# Run: 228, exploration: 0.01, score: 328
# Scores: (min: 11, avg: 128.71, max: 433)
#
# Run: 229, exploration: 0.01, score: 147
# Scores: (min: 11, avg: 129.11, max: 433)
#
# Run: 230, exploration: 0.01, score: 305
# Scores: (min: 11, avg: 131.53, max: 433)
#
# Run: 231, exploration: 0.01, score: 103
# Scores: (min: 11, avg: 131.72, max: 433)
#
# Run: 232, exploration: 0.01, score: 107
# Scores: (min: 11, avg: 132.08, max: 433)
#
# Run: 233, exploration: 0.01, score: 108
# Scores: (min: 11, avg: 131.36, max: 433)
#
# Run: 234, exploration: 0.01, score: 23
# Scores: (min: 11, avg: 131.05, max: 433)
#
# Run: 235, exploration: 0.01, score: 63
# Scores: (min: 11, avg: 130.92, max: 433)
#
# Run: 236, exploration: 0.01, score: 202
# Scores: (min: 11, avg: 130.98, max: 433)
#
# Run: 237, exploration: 0.01, score: 63
# Scores: (min: 11, avg: 131.15, max: 433)
#
# Run: 238, exploration: 0.01, score: 99
# Scores: (min: 11, avg: 131.61, max: 433)
#
# Run: 239, exploration: 0.01, score: 54
# Scores: (min: 11, avg: 130.42, max: 433)
#
# Run: 240, exploration: 0.01, score: 171
# Scores: (min: 11, avg: 130.29, max: 433)
#
# Run: 241, exploration: 0.01, score: 117
# Scores: (min: 11, avg: 130.89, max: 433)
#
# Run: 242, exploration: 0.01, score: 96
# Scores: (min: 11, avg: 130.51, max: 433)
#
# Run: 243, exploration: 0.01, score: 163
# Scores: (min: 11, avg: 131.03, max: 433)
#
# Run: 244, exploration: 0.01, score: 36
# Scores: (min: 11, avg: 128.51, max: 433)
#
# Run: 245, exploration: 0.01, score: 105
# Scores: (min: 11, avg: 127.1, max: 433)
#
# Run: 246, exploration: 0.01, score: 226
# Scores: (min: 11, avg: 125.03, max: 383)
#
# Run: 247, exploration: 0.01, score: 78
# Scores: (min: 11, avg: 125.42, max: 383)
#
# Run: 248, exploration: 0.01, score: 68
# Scores: (min: 11, avg: 125.84, max: 383)
#
# Run: 249, exploration: 0.01, score: 12
# Scores: (min: 11, avg: 125.05, max: 383)
#
# Run: 250, exploration: 0.01, score: 25
# Scores: (min: 11, avg: 124.14, max: 383)
#
# Run: 251, exploration: 0.01, score: 21
# Scores: (min: 11, avg: 123.48, max: 383)
#
# Run: 252, exploration: 0.01, score: 93
# Scores: (min: 11, avg: 123.71, max: 383)
#
# Run: 253, exploration: 0.01, score: 239
# Scores: (min: 11, avg: 123.9, max: 383)
#
# Run: 254, exploration: 0.01, score: 98
# Scores: (min: 11, avg: 123.51, max: 383)
#
# Run: 255, exploration: 0.01, score: 136
# Scores: (min: 11, avg: 123.57, max: 383)
#
# Run: 256, exploration: 0.01, score: 145
# Scores: (min: 11, avg: 121.82, max: 383)
#
# Run: 257, exploration: 0.01, score: 54
# Scores: (min: 11, avg: 121.6, max: 383)
#
# Run: 258, exploration: 0.01, score: 161
# Scores: (min: 11, avg: 122.91, max: 383)
#
# Run: 259, exploration: 0.01, score: 130
# Scores: (min: 11, avg: 123.75, max: 383)
#
# Run: 260, exploration: 0.01, score: 123
# Scores: (min: 11, avg: 123.81, max: 383)
#
# Run: 261, exploration: 0.01, score: 94
# Scores: (min: 11, avg: 123.52, max: 383)
#
# Run: 262, exploration: 0.01, score: 88
# Scores: (min: 11, avg: 123.94, max: 383)
#
# Run: 263, exploration: 0.01, score: 316
# Scores: (min: 11, avg: 126.47, max: 383)
#
# Run: 264, exploration: 0.01, score: 35
# Scores: (min: 11, avg: 126.03, max: 383)
#
# Run: 265, exploration: 0.01, score: 17
# Scores: (min: 11, avg: 124.13, max: 383)
#
# Run: 266, exploration: 0.01, score: 118
# Scores: (min: 11, avg: 124.16, max: 383)
#
# Run: 267, exploration: 0.01, score: 153
# Scores: (min: 11, avg: 123.92, max: 383)
#
# Run: 268, exploration: 0.01, score: 32
# Scores: (min: 11, avg: 122.8, max: 383)
#
# Run: 269, exploration: 0.01, score: 164
# Scores: (min: 11, avg: 123.7, max: 383)
#
# Run: 270, exploration: 0.01, score: 28
# Scores: (min: 11, avg: 123.55, max: 383)
#
# Run: 271, exploration: 0.01, score: 53
# Scores: (min: 11, avg: 123.71, max: 383)
#
# Run: 272, exploration: 0.01, score: 59
# Scores: (min: 11, avg: 124.15, max: 383)
#
# Run: 273, exploration: 0.01, score: 102
# Scores: (min: 11, avg: 124.72, max: 383)
#
# Run: 274, exploration: 0.01, score: 35
# Scores: (min: 11, avg: 122.08, max: 383)
#
# Run: 275, exploration: 0.01, score: 179
# Scores: (min: 11, avg: 123.42, max: 383)
#
# Run: 276, exploration: 0.01, score: 91
# Scores: (min: 12, avg: 124.22, max: 383)
#
# Run: 277, exploration: 0.01, score: 13
# Scores: (min: 12, avg: 124.23, max: 383)
#
# Run: 278, exploration: 0.01, score: 116
# Scores: (min: 12, avg: 125.08, max: 383)
#
# Run: 279, exploration: 0.01, score: 58
# Scores: (min: 12, avg: 124.38, max: 383)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-5917cc743759> in <module>
#      83             dqn_solver.experience_replay()
#      84
# ---> 85 cartpole()
#
# <ipython-input-3-5917cc743759> in cartpole()
#      81                 score_logger.add_score(step, run)
#      82                 break
# ---> 83             dqn_solver.experience_replay()
#      84
#      85 cartpole()
#
# <ipython-input-3-5917cc743759> in experience_replay(self)
#      48             q_update = reward
#      49             if not terminal:
# ---> 50                 q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))
#      51             q_values = self.model.predict(state)
#      52             q_values[0][action] = q_update
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# -> 1462                                             callbacks=callbacks)
#    1463
#    1464     def train_on_batch(self, x, y,
#
# C:\ProgramData\Anaconda3\lib\site-packages\keras\engine\training_arrays.py in predict_loop(model, f, ins, batch_size, verbose, steps, callbacks)
#     322             batch_logs = {'batch': batch_index, 'size': len(batch_ids)}
#     323             callbacks._call_batch_hook('predict', 'begin', batch_index, batch_logs)
# --> 324             batch_outs = f(ins_batch)
#     325             batch_outs = to_list(batch_outs)
#     326             if batch_index == 0:
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\keras\backend.py in __call__(self, inputs)
#    3725         value = math_ops.cast(value, tensor.dtype)
#    3726       converted_inputs.append(value)
# -> 3727     outputs = self._graph_fn(*converted_inputs)
#    3728
#    3729     # EagerTensor.numpy() will often make a copy to ensure memory safety.
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in __call__(self, *args, **kwargs)
#    1549       TypeError: For invalid positional/keyword argument combinations.
#    1550     """
# -> 1551     return self._call_impl(args, kwargs)
#    1552
#    1553   def _call_impl(self, args, kwargs, cancellation_manager=None):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_impl(self, args, kwargs, cancellation_manager)
#    1589       raise TypeError("Keyword arguments {} unknown. Expected {}.".format(
#    1590           list(kwargs.keys()), list(self._arg_keywords)))
# -> 1591     return self._call_flat(args, self.captured_inputs, cancellation_manager)
#    1592
#    1593   def _filtered_call(self, args, kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1690       # No tape is watching; skip to running the function.
#    1691       return self._build_call_outputs(self._inference_function.call(
# -> 1692           ctx, args, cancellation_manager=cancellation_manager))
#    1693     forward_backward = self._select_forward_and_backward_functions(
#    1694         args,
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     543               inputs=args,
#     544               attrs=("executor_type", executor_type, "config_proto", config),
# --> 545               ctx=ctx)
#     546         else:
#     547           outputs = execute.execute_with_cancellation(
#
# C:\ProgramData\Anaconda3\lib\site-packages\tensorflow_core\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      59     tensors = pywrap_tensorflow.TFE_Py_Execute(ctx._handle, device_name,
#      60                                                op_name, inputs, attrs,
# ---> 61                                                num_outputs)
#      62   except core._NotOkStatusException as e:
#      63     if name is not None:
#
# KeyboardInterrupt:

# %%
# modifying exploration factor
# original MAX = 1.0
# experiment MAX = 1.0
# original MIN = 0.01
# experiment MIN = 0.05
# original DECAY = 0.995
# experiment DECAY = 0.9999
# Solved after 300 total runs.

ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.05  
EXPLORATION_DECAY = 0.9999  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 17
# Scores: (min: 17, avg: 17, max: 17)
#
# Run: 2, exploration: 0.9982015291843062, score: 21
# Scores: (min: 17, avg: 19, max: 21)
#
# Run: 3, exploration: 0.9962070215713769, score: 21
# Scores: (min: 17, avg: 19.666666666666668, max: 21)
#
# Run: 4, exploration: 0.9945148237990713, score: 18
# Scores: (min: 17, avg: 19.25, max: 21)
#
# Run: 5, exploration: 0.9921307310710261, score: 25
# Scores: (min: 17, avg: 20.4, max: 25)
#
# Run: 6, exploration: 0.9908417346989258, score: 14
# Scores: (min: 14, avg: 19.333333333333332, max: 25)
#
# Run: 7, exploration: 0.9889608287826225, score: 20
# Scores: (min: 14, avg: 19.428571428571427, max: 25)
#
# Run: 8, exploration: 0.9851112007201276, score: 40
# Scores: (min: 14, avg: 22, max: 40)
#
# Run: 9, exploration: 0.9836345678377172, score: 16
# Scores: (min: 14, avg: 21.333333333333332, max: 40)
#
# Run: 10, exploration: 0.9799036631402607, score: 39
# Scores: (min: 14, avg: 23.1, max: 40)
#
# Run: 11, exploration: 0.9779457165143248, score: 21
# Scores: (min: 14, avg: 22.90909090909091, max: 40)
#
# Run: 12, exploration: 0.977065917347785, score: 10
# Scores: (min: 10, avg: 21.833333333333332, max: 40)
#
# Run: 13, exploration: 0.9744312660161123, score: 28
# Scores: (min: 10, avg: 22.307692307692307, max: 40)
#
# Run: 14, exploration: 0.9726787798222825, score: 19
# Scores: (min: 10, avg: 22.071428571428573, max: 40)
#
# Run: 15, exploration: 0.9700559583759003, score: 28
# Scores: (min: 10, avg: 22.466666666666665, max: 40)
#
# Run: 16, exploration: 0.9689894301924369, score: 12
# Scores: (min: 10, avg: 21.8125, max: 40)
#
# Run: 17, exploration: 0.967633726417934, score: 15
# Scores: (min: 10, avg: 21.41176470588235, max: 40)
#
# Run: 18, exploration: 0.9664732043716606, score: 13
# Scores: (min: 10, avg: 20.944444444444443, max: 40)
#
# Run: 19, exploration: 0.9641563341920976, score: 25
# Scores: (min: 10, avg: 21.157894736842106, max: 40)
#
# Run: 20, exploration: 0.9612680553577415, score: 31
# Scores: (min: 10, avg: 21.65, max: 40)
#
# Run: 21, exploration: 0.9558041411915943, score: 58
# Scores: (min: 10, avg: 23.38095238095238, max: 58)
#
# Run: 22, exploration: 0.9546578068426682, score: 13
# Scores: (min: 10, avg: 22.90909090909091, max: 58)
#
# Run: 23, exploration: 0.9498012040578938, score: 52
# Scores: (min: 10, avg: 24.17391304347826, max: 58)
#
# Run: 24, exploration: 0.9468612326345439, score: 32
# Scores: (min: 10, avg: 24.5, max: 58)
#
# Run: 25, exploration: 0.9453473903657377, score: 17
# Scores: (min: 10, avg: 24.2, max: 58)
#
# Run: 26, exploration: 0.9419500887047652, score: 37
# Scores: (min: 10, avg: 24.692307692307693, max: 58)
#
# Run: 27, exploration: 0.9399739703614417, score: 22
# Scores: (min: 10, avg: 24.59259259259259, max: 58)
#
# Run: 28, exploration: 0.9383772923374687, score: 18
# Scores: (min: 10, avg: 24.357142857142858, max: 58)
#
# Run: 29, exploration: 0.9376268531966981, score: 9
# Scores: (min: 9, avg: 23.82758620689655, max: 58)
#
# Run: 30, exploration: 0.9361277748589067, score: 17
# Scores: (min: 9, avg: 23.6, max: 58)
#
# Run: 31, exploration: 0.9343507319584249, score: 20
# Scores: (min: 9, avg: 23.483870967741936, max: 58)
#
# Run: 32, exploration: 0.9322040875283647, score: 24
# Scores: (min: 9, avg: 23.5, max: 58)
#
# Run: 33, exploration: 0.9302484153338654, score: 22
# Scores: (min: 9, avg: 23.454545454545453, max: 58)
#
# Run: 34, exploration: 0.9292256535601664, score: 12
# Scores: (min: 9, avg: 23.11764705882353, max: 58)
#
# Run: 35, exploration: 0.9269980747746605, score: 25
# Scores: (min: 9, avg: 23.17142857142857, max: 58)
#
# Run: 36, exploration: 0.924036274251254, score: 33
# Scores: (min: 9, avg: 23.444444444444443, max: 58)
#
# Run: 37, exploration: 0.9229280403828515, score: 13
# Scores: (min: 9, avg: 23.16216216216216, max: 58)
#
# Run: 38, exploration: 0.9204393714532942, score: 28
# Scores: (min: 9, avg: 23.289473684210527, max: 58)
#
# Run: 39, exploration: 0.9174067764292271, score: 34
# Scores: (min: 9, avg: 23.564102564102566, max: 58)
#
# Run: 40, exploration: 0.9149329955488482, score: 28
# Scores: (min: 9, avg: 23.675, max: 58)
#
# Run: 41, exploration: 0.9135615563190007, score: 16
# Scores: (min: 9, avg: 23.48780487804878, max: 58)
#
# Run: 42, exploration: 0.9121921728086106, score: 16
# Scores: (min: 9, avg: 23.30952380952381, max: 58)
#
# Run: 43, exploration: 0.9107337594520628, score: 17
# Scores: (min: 9, avg: 23.162790697674417, max: 58)
#
# Run: 44, exploration: 0.9098234354135336, score: 11
# Scores: (min: 9, avg: 22.886363636363637, max: 58)
#
# Run: 45, exploration: 0.9085505102121963, score: 15
# Scores: (min: 9, avg: 22.711111111111112, max: 58)
#
# Run: 46, exploration: 0.907370102958538, score: 14
# Scores: (min: 9, avg: 22.52173913043478, max: 58)
#
# Run: 47, exploration: 0.905919399129966, score: 17
# Scores: (min: 9, avg: 22.404255319148938, max: 58)
#
# Run: 48, exploration: 0.9049233858971459, score: 12
# Scores: (min: 9, avg: 22.1875, max: 58)
#
# Run: 49, exploration: 0.8996897607585478, score: 59
# Scores: (min: 9, avg: 22.93877551020408, max: 59)
#
# Run: 50, exploration: 0.8982513362653847, score: 17
# Scores: (min: 9, avg: 22.82, max: 59)
#
# Run: 51, exploration: 0.8954709299568612, score: 32
# Scores: (min: 9, avg: 23, max: 59)
#
# Run: 52, exploration: 0.893502961070434, score: 23
# Scores: (min: 9, avg: 23, max: 59)
#
# Run: 53, exploration: 0.8919852205932721, score: 18
# Scores: (min: 9, avg: 22.90566037735849, max: 59)
#
# Run: 54, exploration: 0.8908263352999289, score: 14
# Scores: (min: 9, avg: 22.74074074074074, max: 59)
#
# Run: 55, exploration: 0.8894910307594268, score: 16
# Scores: (min: 9, avg: 22.618181818181817, max: 59)
#
# Run: 56, exploration: 0.8880689120014957, score: 17
# Scores: (min: 9, avg: 22.517857142857142, max: 59)
#
# Run: 57, exploration: 0.8868264233442354, score: 15
# Scores: (min: 9, avg: 22.385964912280702, max: 59)
#
# Run: 58, exploration: 0.885762816746604, score: 13
# Scores: (min: 9, avg: 22.224137931034484, max: 59)
#
# Run: 59, exploration: 0.8846120157265657, score: 14
# Scores: (min: 9, avg: 22.084745762711865, max: 59)
#
# Run: 60, exploration: 0.8828444714499131, score: 21
# Scores: (min: 9, avg: 22.066666666666666, max: 59)
#
# Run: 61, exploration: 0.880640006775277, score: 26
# Scores: (min: 9, avg: 22.131147540983605, max: 59)
#
# Run: 62, exploration: 0.8795838197958541, score: 13
# Scores: (min: 9, avg: 21.983870967741936, max: 59)
#
# Run: 63, exploration: 0.8785288995439554, score: 13
# Scores: (min: 9, avg: 21.841269841269842, max: 59)
#
# Run: 64, exploration: 0.8730986001712624, score: 63
# Scores: (min: 9, avg: 22.484375, max: 63)
#
# Run: 65, exploration: 0.8713540608633507, score: 21
# Scores: (min: 9, avg: 22.46153846153846, max: 63)
#
# Run: 66, exploration: 0.8686569111570615, score: 32
# Scores: (min: 9, avg: 22.606060606060606, max: 63)
#
# Run: 67, exploration: 0.8648430267496409, score: 45
# Scores: (min: 9, avg: 22.940298507462686, max: 63)
#
# Run: 68, exploration: 0.8635466699013089, score: 16
# Scores: (min: 9, avg: 22.83823529411765, max: 63)
#
# Run: 69, exploration: 0.8604433360730452, score: 37
# Scores: (min: 9, avg: 23.043478260869566, max: 63)
#
# Run: 70, exploration: 0.8591535741430544, score: 16
# Scores: (min: 9, avg: 22.942857142857143, max: 63)
#
# Run: 71, exploration: 0.8474628499532834, score: 138
# Scores: (min: 9, avg: 24.56338028169014, max: 138)
#
# Run: 72, exploration: 0.8417193653748032, score: 69
# Scores: (min: 9, avg: 25.180555555555557, max: 138)
#
# Run: 73, exploration: 0.8366002504607994, score: 62
# Scores: (min: 9, avg: 25.684931506849313, max: 138)
#
# Run: 74, exploration: 0.8355968821324011, score: 13
# Scores: (min: 9, avg: 25.513513513513512, max: 138)
#
# Run: 75, exploration: 0.8335937541723177, score: 25
# Scores: (min: 9, avg: 25.506666666666668, max: 138)
#
# Run: 76, exploration: 0.8280270669077725, score: 68
# Scores: (min: 9, avg: 26.06578947368421, max: 138)
#
# Run: 77, exploration: 0.8268685822174137, score: 15
# Scores: (min: 9, avg: 25.92207792207792, max: 138)
#
# Run: 78, exploration: 0.8256291471799866, score: 16
# Scores: (min: 9, avg: 25.794871794871796, max: 138)
#
# Run: 79, exploration: 0.8236499142930047, score: 25
# Scores: (min: 9, avg: 25.78481012658228, max: 138)
#
# Run: 80, exploration: 0.8227443522588603, score: 12
# Scores: (min: 9, avg: 25.6125, max: 138)
#
# Run: 81, exploration: 0.817658864300209, score: 63
# Scores: (min: 9, avg: 26.074074074074073, max: 138)
#
# Run: 82, exploration: 0.8060489706275987, score: 144
# Scores: (min: 9, avg: 27.51219512195122, max: 144)
#
# Run: 83, exploration: 0.8037950777359838, score: 29
# Scores: (min: 9, avg: 27.53012048192771, max: 144)
#
# Run: 84, exploration: 0.7995460213139653, score: 54
# Scores: (min: 9, avg: 27.845238095238095, max: 144)
#
# Run: 85, exploration: 0.7985870936129023, score: 13
# Scores: (min: 9, avg: 27.67058823529412, max: 144)
#
# Run: 86, exploration: 0.797629315992399, score: 13
# Scores: (min: 9, avg: 27.5, max: 144)
#
# Run: 87, exploration: 0.7951603705063066, score: 32
# Scores: (min: 9, avg: 27.551724137931036, max: 144)
#
# Run: 88, exploration: 0.792699067281715, score: 32
# Scores: (min: 9, avg: 27.602272727272727, max: 144)
#
# Run: 89, exploration: 0.7897713539545212, score: 38
# Scores: (min: 9, avg: 27.719101123595507, max: 144)
#
# Run: 90, exploration: 0.7845757675308773, score: 67
# Scores: (min: 9, avg: 28.155555555555555, max: 144)
#
# Run: 91, exploration: 0.7824601645259803, score: 28
# Scores: (min: 9, avg: 28.153846153846153, max: 144)
#
# Run: 92, exploration: 0.7808967299796155, score: 21
# Scores: (min: 9, avg: 28.07608695652174, max: 144)
#
# Run: 93, exploration: 0.7791026417871125, score: 24
# Scores: (min: 9, avg: 28.032258064516128, max: 144)
#
# Run: 94, exploration: 0.7760699075209033, score: 40
# Scores: (min: 9, avg: 28.159574468085108, max: 144)
#
# Run: 95, exploration: 0.7741320591778444, score: 26
# Scores: (min: 9, avg: 28.13684210526316, max: 144)
#
# Run: 96, exploration: 0.7693470500136413, score: 63
# Scores: (min: 9, avg: 28.5, max: 144)
#
# Run: 97, exploration: 0.7672725111377597, score: 28
# Scores: (min: 9, avg: 28.49484536082474, max: 144)
#
# Run: 98, exploration: 0.7622249355044552, score: 67
# Scores: (min: 9, avg: 28.887755102040817, max: 144)
#
# Run: 99, exploration: 0.7610823980906727, score: 16
# Scores: (min: 9, avg: 28.757575757575758, max: 144)
#
# Run: 100, exploration: 0.7597895925686249, score: 18
# Scores: (min: 9, avg: 28.65, max: 144)
#
# Run: 101, exploration: 0.7579681930287285, score: 25
# Scores: (min: 9, avg: 28.73, max: 144)
#
# Run: 102, exploration: 0.7534337740068217, score: 61
# Scores: (min: 9, avg: 29.13, max: 144)
#
# Run: 103, exploration: 0.7518531442907166, score: 22
# Scores: (min: 9, avg: 29.14, max: 144)
#
# Run: 104, exploration: 0.7472058439458807, score: 63
# Scores: (min: 9, avg: 29.59, max: 144)
#
# Run: 105, exploration: 0.73984463612856, score: 100
# Scores: (min: 9, avg: 30.34, max: 144)
#
# Run: 106, exploration: 0.7379234426472027, score: 27
# Scores: (min: 9, avg: 30.47, max: 144)
#
# Run: 107, exploration: 0.7368910210692992, score: 15
# Scores: (min: 9, avg: 30.42, max: 144)
#
# Run: 108, exploration: 0.7357864579380827, score: 16
# Scores: (min: 9, avg: 30.18, max: 144)
#
# Run: 109, exploration: 0.732116524628018, score: 51
# Scores: (min: 9, avg: 30.53, max: 144)
#
# Run: 110, exploration: 0.7302884279830798, score: 26
# Scores: (min: 9, avg: 30.4, max: 144)
#
# Run: 111, exploration: 0.7276639852494771, score: 37
# Scores: (min: 9, avg: 30.56, max: 144)
#
# Run: 112, exploration: 0.7255567113508772, score: 30
# Scores: (min: 9, avg: 30.76, max: 144)
#
# Run: 113, exploration: 0.7241793935985041, score: 20
# Scores: (min: 9, avg: 30.68, max: 144)
#
# Run: 114, exploration: 0.7211440670244899, score: 43
# Scores: (min: 9, avg: 30.92, max: 144)
#
# Run: 115, exploration: 0.717403664328512, score: 53
# Scores: (min: 9, avg: 31.17, max: 144)
#
# Run: 116, exploration: 0.7114735613771402, score: 84
# Scores: (min: 9, avg: 31.89, max: 144)
#
# Run: 117, exploration: 0.7092712984930953, score: 32
# Scores: (min: 9, avg: 32.06, max: 144)
#
# Run: 118, exploration: 0.706015980722793, score: 47
# Scores: (min: 9, avg: 32.4, max: 144)
#
# Run: 119, exploration: 0.7036898519016507, score: 34
# Scores: (min: 9, avg: 32.49, max: 144)
#
# Run: 120, exploration: 0.7010207714729464, score: 39
# Scores: (min: 9, avg: 32.57, max: 144)
#
# Run: 121, exploration: 0.6967573482538838, score: 62
# Scores: (min: 9, avg: 32.61, max: 144)
#
# Run: 122, exploration: 0.6952260905247033, score: 23
# Scores: (min: 9, avg: 32.71, max: 144)
#
# Run: 123, exploration: 0.6921044460007305, score: 46
# Scores: (min: 9, avg: 32.65, max: 144)
#
# Run: 124, exploration: 0.6909288092341097, score: 18
# Scores: (min: 9, avg: 32.51, max: 144)
#
# Run: 125, exploration: 0.6887901396408949, score: 32
# Scores: (min: 9, avg: 32.66, max: 144)
#
# Run: 126, exploration: 0.6877576773477748, score: 16
# Scores: (min: 9, avg: 32.45, max: 144)
#
# Run: 127, exploration: 0.6833698647964354, score: 65
# Scores: (min: 9, avg: 32.88, max: 144)
#
# Run: 128, exploration: 0.6723879178367465, score: 163
# Scores: (min: 9, avg: 34.33, max: 163)
#
# Run: 129, exploration: 0.6692349522455187, score: 48
# Scores: (min: 11, avg: 34.72, max: 163)
#
# Run: 130, exploration: 0.6661633878988705, score: 47
# Scores: (min: 11, avg: 35.02, max: 163)
#
# Run: 131, exploration: 0.6625756218998273, score: 55
# Scores: (min: 11, avg: 35.37, max: 163)
#
# Run: 132, exploration: 0.655916958039319, score: 102
# Scores: (min: 11, avg: 36.15, max: 163)
#
# Run: 133, exploration: 0.6544100073446841, score: 24
# Scores: (min: 11, avg: 36.17, max: 163)
#
# Run: 134, exploration: 0.652775944052029, score: 26
# Scores: (min: 11, avg: 36.31, max: 163)
#
# Run: 135, exploration: 0.6486761784351415, score: 64
# Scores: (min: 11, avg: 36.7, max: 163)
#
# Run: 136, exploration: 0.6477038449824171, score: 16
# Scores: (min: 11, avg: 36.53, max: 163)
#
# Run: 137, exploration: 0.647056432526454, score: 11
# Scores: (min: 11, avg: 36.51, max: 163)
#
# Run: 138, exploration: 0.644151075266669, score: 46
# Scores: (min: 11, avg: 36.69, max: 163)
#
# Run: 139, exploration: 0.6350683160703967, score: 143
# Scores: (min: 11, avg: 37.78, max: 163)
#
# Run: 140, exploration: 0.6336092645421306, score: 24
# Scores: (min: 11, avg: 37.74, max: 163)
#
# Run: 141, exploration: 0.6323432491486414, score: 21
# Scores: (min: 11, avg: 37.79, max: 163)
#
# Run: 142, exploration: 0.628497504485222, score: 62
# Scores: (min: 11, avg: 38.25, max: 163)
#
# Run: 143, exploration: 0.6253627037531362, score: 51
# Scores: (min: 11, avg: 38.59, max: 163)
#
# Run: 144, exploration: 0.6227415575980831, score: 43
# Scores: (min: 11, avg: 38.91, max: 163)
#
# Run: 145, exploration: 0.6124276189835018, score: 168
# Scores: (min: 11, avg: 40.44, max: 168)
#
# Run: 146, exploration: 0.6118766545489235, score: 10
# Scores: (min: 10, avg: 40.4, max: 168)
#
# Run: 147, exploration: 0.6094948640152816, score: 40
# Scores: (min: 10, avg: 40.63, max: 168)
#
# Run: 148, exploration: 0.6063335591709474, score: 53
# Scores: (min: 10, avg: 41.04, max: 168)
#
# Run: 149, exploration: 0.6034299870541165, score: 49
# Scores: (min: 10, avg: 40.94, max: 168)
#
# Run: 150, exploration: 0.6024652228530034, score: 17
# Scores: (min: 10, avg: 40.94, max: 168)
#
# Run: 151, exploration: 0.600360175301112, score: 36
# Scores: (min: 10, avg: 40.98, max: 168)
#
# Run: 152, exploration: 0.5985617039061534, score: 31
# Scores: (min: 10, avg: 41.06, max: 168)
#
# Run: 153, exploration: 0.5956357796274213, score: 50
# Scores: (min: 10, avg: 41.38, max: 168)
#
# Run: 154, exploration: 0.5938514608875307, score: 31
# Scores: (min: 10, avg: 41.55, max: 168)
#
# Run: 155, exploration: 0.5931392309458121, score: 13
# Scores: (min: 10, avg: 41.52, max: 168)
#
# Run: 156, exploration: 0.5919540787725678, score: 21
# Scores: (min: 10, avg: 41.56, max: 168)
#
# Run: 157, exploration: 0.586356864026631, score: 96
# Scores: (min: 10, avg: 42.37, max: 168)
#
# Run: 158, exploration: 0.5837824330030914, score: 45
# Scores: (min: 10, avg: 42.69, max: 168)
#
# Run: 159, exploration: 0.5790726601352557, score: 82
# Scores: (min: 10, avg: 43.37, max: 168)
#
# Run: 160, exploration: 0.5769916425853577, score: 37
# Scores: (min: 10, avg: 43.53, max: 168)
#
# Run: 161, exploration: 0.5754357887043543, score: 28
# Scores: (min: 10, avg: 43.55, max: 168)
#
# Run: 162, exploration: 0.5672652072871398, score: 144
# Scores: (min: 10, avg: 44.86, max: 168)
#
# Run: 163, exploration: 0.5646616499266786, score: 47
# Scores: (min: 10, avg: 45.2, max: 168)
#
# Run: 164, exploration: 0.5639844284992579, score: 13
# Scores: (min: 10, avg: 44.7, max: 168)
#
# Run: 165, exploration: 0.5566997198910414, score: 131
# Scores: (min: 10, avg: 45.8, max: 168)
#
# Run: 166, exploration: 0.5527056780082905, score: 73
# Scores: (min: 10, avg: 46.21, max: 168)
#
# Run: 167, exploration: 0.550994858005194, score: 32
# Scores: (min: 10, avg: 46.08, max: 168)
#
# Run: 168, exploration: 0.549344268023281, score: 31
# Scores: (min: 10, avg: 46.23, max: 168)
#
# Run: 169, exploration: 0.5448578401946368, score: 83
# Scores: (min: 10, avg: 46.69, max: 168)
#
# Run: 170, exploration: 0.5418691989367118, score: 56
# Scores: (min: 10, avg: 47.09, max: 168)
#
# Run: 171, exploration: 0.5412193134124749, score: 13
# Scores: (min: 10, avg: 45.84, max: 168)
#
# Run: 172, exploration: 0.5341752276990839, score: 132
# Scores: (min: 10, avg: 46.47, max: 168)
#
# Run: 173, exploration: 0.529547830212172, score: 88
# Scores: (min: 10, avg: 46.73, max: 168)
#
# Run: 174, exploration: 0.5259589415705532, score: 69
# Scores: (min: 10, avg: 47.29, max: 168)
#
# Run: 175, exploration: 0.5241212112911097, score: 36
# Scores: (min: 10, avg: 47.4, max: 168)
#
# Run: 176, exploration: 0.5213505789988279, score: 54
# Scores: (min: 10, avg: 47.26, max: 168)
#
# Run: 177, exploration: 0.5175583884960994, score: 74
# Scores: (min: 10, avg: 47.85, max: 168)
#
# Run: 178, exploration: 0.5108222548070325, score: 132
# Scores: (min: 10, avg: 49.01, max: 168)
#
# Run: 179, exploration: 0.508986509225669, score: 37
# Scores: (min: 10, avg: 49.13, max: 168)
#
# Run: 180, exploration: 0.5033677200029918, score: 112
# Scores: (min: 10, avg: 50.13, max: 168)
#
# Run: 181, exploration: 0.4979105346844089, score: 110
# Scores: (min: 10, avg: 50.6, max: 168)
#
# Run: 182, exploration: 0.49681628091502034, score: 23
# Scores: (min: 10, avg: 49.39, max: 168)
#
# Run: 183, exploration: 0.4931532272954633, score: 75
# Scores: (min: 10, avg: 49.85, max: 168)
#
# Run: 184, exploration: 0.48658872620790233, score: 135
# Scores: (min: 10, avg: 50.66, max: 168)
#
# Run: 185, exploration: 0.48547080234578366, score: 24
# Scores: (min: 10, avg: 50.77, max: 168)
#
# Run: 186, exploration: 0.4769531468898265, score: 178
# Scores: (min: 10, avg: 52.42, max: 178)
#
# Run: 187, exploration: 0.47642876067379697, score: 12
# Scores: (min: 10, avg: 52.22, max: 178)
#
# Run: 188, exploration: 0.46928837495411807, score: 152
# Scores: (min: 10, avg: 53.42, max: 178)
#
# Run: 189, exploration: 0.4553270451765506, score: 303
# Scores: (min: 10, avg: 56.07, max: 303)
#
# Run: 190, exploration: 0.45314660358228837, score: 49
# Scores: (min: 10, avg: 55.89, max: 303)
#
# Run: 191, exploration: 0.44479556463011005, score: 187
# Scores: (min: 10, avg: 57.48, max: 303)
#
# Run: 192, exploration: 0.43834840581092804, score: 147
# Scores: (min: 10, avg: 58.74, max: 303)
#
# Run: 193, exploration: 0.4358568031295854, score: 58
# Scores: (min: 10, avg: 59.08, max: 303)
#
# Run: 194, exploration: 0.43468151834439817, score: 28
# Scores: (min: 10, avg: 58.96, max: 303)
#
# Run: 195, exploration: 0.43247017574881086, score: 52
# Scores: (min: 10, avg: 59.22, max: 303)
#
# Run: 196, exploration: 0.42846664819458646, score: 94
# Scores: (min: 10, avg: 59.53, max: 303)
#
# Run: 197, exploration: 0.42624429363420574, score: 53
# Scores: (min: 10, avg: 59.78, max: 303)
#
# Run: 198, exploration: 0.4251799606531784, score: 26
# Scores: (min: 10, avg: 59.37, max: 303)
#
# Run: 199, exploration: 0.41772011673646525, score: 178
# Scores: (min: 10, avg: 60.99, max: 303)
#
# Run: 200, exploration: 0.4114596156866346, score: 152
# Scores: (min: 10, avg: 62.33, max: 303)
#
# Run: 201, exploration: 0.40468542866846985, score: 167
# Scores: (min: 10, avg: 63.75, max: 303)
#
# Run: 202, exploration: 0.4040788252610906, score: 16
# Scores: (min: 10, avg: 63.3, max: 303)
#
# Run: 203, exploration: 0.39489062226008853, score: 231
# Scores: (min: 10, avg: 65.39, max: 303)
#
# Run: 204, exploration: 0.3907657579165237, score: 106
# Scores: (min: 10, avg: 65.82, max: 303)
#
# Run: 205, exploration: 0.3834492778017982, score: 190
# Scores: (min: 10, avg: 66.72, max: 303)
#
# Run: 206, exploration: 0.3813841293618728, score: 55
# Scores: (min: 10, avg: 67, max: 303)
#
# Run: 207, exploration: 0.38066015131353315, score: 20
# Scores: (min: 10, avg: 67.05, max: 303)
#
# Run: 208, exploration: 0.3757057776112747, score: 132
# Scores: (min: 10, avg: 68.21, max: 303)
#
# Run: 209, exploration: 0.3661726874030757, score: 258
# Scores: (min: 10, avg: 70.28, max: 303)
#
# Run: 210, exploration: 0.35820446174312376, score: 221
# Scores: (min: 10, avg: 72.23, max: 303)
#
# Run: 211, exploration: 0.3509707636288508, score: 205
# Scores: (min: 10, avg: 73.91, max: 303)
#
# Run: 212, exploration: 0.3456069530272577, score: 155
# Scores: (min: 10, avg: 75.16, max: 303)
#
# Run: 213, exploration: 0.33859379036091364, score: 206
# Scores: (min: 10, avg: 77.02, max: 303)
#
# Run: 214, exploration: 0.3356270892989284, score: 89
# Scores: (min: 10, avg: 77.48, max: 303)
#
# Run: 215, exploration: 0.3290138000336249, score: 200
# Scores: (min: 10, avg: 78.95, max: 303)
#
# Run: 216, exploration: 0.32031290789275735, score: 269
# Scores: (min: 10, avg: 80.8, max: 303)
#
# Run: 217, exploration: 0.3176334151154381, score: 85
# Scores: (min: 10, avg: 81.33, max: 303)
#
# Run: 218, exploration: 0.3110012340223759, score: 212
# Scores: (min: 10, avg: 82.98, max: 303)
#
# Run: 219, exploration: 0.3038383191457641, score: 234
# Scores: (min: 10, avg: 84.98, max: 303)
#
# Run: 220, exploration: 0.29639542999381663, score: 249
# Scores: (min: 10, avg: 87.08, max: 303)
#
# Run: 221, exploration: 0.28838405175557963, score: 275
# Scores: (min: 10, avg: 89.21, max: 303)
#
# Run: 222, exploration: 0.2835794312729053, score: 169
# Scores: (min: 10, avg: 90.67, max: 303)
#
# Run: 223, exploration: 0.2763839382551971, score: 258
# Scores: (min: 10, avg: 92.79, max: 303)
#
# Run: 224, exploration: 0.27459317938869315, score: 66
# Scores: (min: 10, avg: 93.27, max: 303)
#
# Run: 225, exploration: 0.268644665315743, score: 220
# Scores: (min: 10, avg: 95.15, max: 303)
#
# Run: 226, exploration: 0.2631932450801195, score: 206
# Scores: (min: 10, avg: 97.05, max: 303)
#
# Run: 227, exploration: 0.25543986998781965, score: 300
# Scores: (min: 10, avg: 99.4, max: 303)
#
# Run: 228, exploration: 0.251989232742831, score: 137
# Scores: (min: 10, avg: 99.14, max: 303)
#
# Run: 229, exploration: 0.246974564679794, score: 202
# Scores: (min: 10, avg: 100.68, max: 303)
#
# Run: 230, exploration: 0.242908425923798, score: 167
# Scores: (min: 10, avg: 101.88, max: 303)
#
# Run: 231, exploration: 0.23605931168993835, score: 287
# Scores: (min: 10, avg: 104.2, max: 303)
#
# Run: 232, exploration: 0.23126912347964446, score: 206
# Scores: (min: 10, avg: 105.24, max: 303)
#
# Run: 233, exploration: 0.22912818438092178, score: 94
# Scores: (min: 10, avg: 105.94, max: 303)
#
# Run: 234, exploration: 0.22490558097248764, score: 187
# Scores: (min: 10, avg: 107.55, max: 303)
#
# Run: 235, exploration: 0.2190454743994215, score: 265
# Scores: (min: 10, avg: 109.56, max: 303)
#
# Run: 236, exploration: 0.21261390405103164, score: 299
# Scores: (min: 10, avg: 112.39, max: 303)
#
# Run: 237, exploration: 0.2078416992700585, score: 228
# Scores: (min: 10, avg: 114.56, max: 303)
#
# Run: 238, exploration: 0.20480862237029615, score: 148
# Scores: (min: 10, avg: 115.58, max: 303)
#
# Run: 239, exploration: 0.20380746490102233, score: 50
# Scores: (min: 10, avg: 114.65, max: 303)
#
# Run: 240, exploration: 0.2019207479729125, score: 94
# Scores: (min: 10, avg: 115.35, max: 303)
#
# Run: 241, exploration: 0.19687598614639276, score: 254
# Scores: (min: 10, avg: 117.68, max: 303)
#
# Run: 242, exploration: 0.19317047100377183, score: 191
# Scores: (min: 10, avg: 118.97, max: 303)
#
# Run: 243, exploration: 0.18943995107540673, score: 196
# Scores: (min: 10, avg: 120.42, max: 303)
#
# Run: 244, exploration: 0.18628378809193785, score: 169
# Scores: (min: 10, avg: 121.68, max: 303)
#
# Run: 245, exploration: 0.1835653102482416, score: 148
# Scores: (min: 10, avg: 121.48, max: 303)
#
# Run: 246, exploration: 0.1792298971235121, score: 240
# Scores: (min: 12, avg: 123.78, max: 303)
#
# Run: 247, exploration: 0.17709188518464908, score: 121
# Scores: (min: 12, avg: 124.59, max: 303)
#
# Run: 248, exploration: 0.17536477501602554, score: 99
# Scores: (min: 12, avg: 125.05, max: 303)
#
# Run: 249, exploration: 0.1725638698816574, score: 162
# Scores: (min: 12, avg: 126.18, max: 303)
#
# Run: 250, exploration: 0.16921438276152992, score: 197
# Scores: (min: 12, avg: 127.98, max: 303)
#
# Run: 251, exploration: 0.16470649931978884, score: 271
# Scores: (min: 12, avg: 130.33, max: 303)
#
# Run: 252, exploration: 0.16038284973777372, score: 267
# Scores: (min: 12, avg: 132.69, max: 303)
#
# Run: 253, exploration: 0.15778967144678935, score: 164
# Scores: (min: 12, avg: 133.83, max: 303)
#
# Run: 254, exploration: 0.15506774450668304, score: 175
# Scores: (min: 12, avg: 135.27, max: 303)
#
# Run: 255, exploration: 0.15166300281012948, score: 223
# Scores: (min: 12, avg: 137.37, max: 303)
#
# Run: 256, exploration: 0.14882334933046878, score: 190
# Scores: (min: 12, avg: 139.06, max: 303)
#
# Run: 257, exploration: 0.1464317160248395, score: 163
# Scores: (min: 12, avg: 139.73, max: 303)
#
# Run: 258, exploration: 0.14409292623532322, score: 162
# Scores: (min: 12, avg: 140.9, max: 303)
#
# Run: 259, exploration: 0.1413243272802566, score: 195
# Scores: (min: 12, avg: 142.03, max: 303)
#
# Run: 260, exploration: 0.13916449801957656, score: 155
# Scores: (min: 12, avg: 143.21, max: 303)
#
# Run: 261, exploration: 0.13878924193549977, score: 28
# Scores: (min: 12, avg: 143.21, max: 303)
#
# Run: 262, exploration: 0.1366954935699908, score: 153
# Scores: (min: 12, avg: 143.3, max: 303)
#
# Run: 263, exploration: 0.1337075125690224, score: 222
# Scores: (min: 12, avg: 145.05, max: 303)
#
# Run: 264, exploration: 0.13293421506129247, score: 59
# Scores: (min: 12, avg: 145.51, max: 303)
#
# Run: 265, exploration: 0.13065411883642583, score: 174
# Scores: (min: 12, avg: 145.94, max: 303)
#
# Run: 266, exploration: 0.12429416096008576, score: 500
# Scores: (min: 12, avg: 150.21, max: 500)
#
# Run: 267, exploration: 0.12156509880853868, score: 223
# Scores: (min: 12, avg: 152.12, max: 500)
#
# Run: 268, exploration: 0.11950390598458155, score: 172
# Scores: (min: 12, avg: 153.53, max: 500)
#
# Run: 269, exploration: 0.11763048956247056, score: 159
# Scores: (min: 12, avg: 154.29, max: 500)
#
# Run: 270, exploration: 0.11198285807551939, score: 493
# Scores: (min: 12, avg: 158.66, max: 500)
#
# Run: 271, exploration: 0.1095679293869819, score: 219
# Scores: (min: 12, avg: 160.72, max: 500)
#
# Run: 272, exploration: 0.10766707655429661, score: 176
# Scores: (min: 12, avg: 161.16, max: 500)
#
# Run: 273, exploration: 0.10274410725311922, score: 469
# Scores: (min: 12, avg: 164.97, max: 500)
#
# Run: 274, exploration: 0.09986707795115528, score: 285
# Scores: (min: 12, avg: 167.13, max: 500)
#
# Run: 275, exploration: 0.09810508413204629, score: 179
# Scores: (min: 12, avg: 168.56, max: 500)
#
# Run: 276, exploration: 0.09597983296999407, score: 220
# Scores: (min: 12, avg: 170.22, max: 500)
#
# Run: 277, exploration: 0.09414509265354484, score: 194
# Scores: (min: 12, avg: 171.42, max: 500)
#
# Run: 278, exploration: 0.09199516083341126, score: 232
# Scores: (min: 12, avg: 172.42, max: 500)
#
# Run: 279, exploration: 0.08952649508478516, score: 273
# Scores: (min: 12, avg: 174.78, max: 500)
#
# Run: 280, exploration: 0.08749078432890559, score: 231
# Scores: (min: 12, avg: 175.97, max: 500)
#
# Run: 281, exploration: 0.08560403122499705, score: 219
# Scores: (min: 12, avg: 177.06, max: 500)
#
# Run: 282, exploration: 0.0851855766000452, score: 50
# Scores: (min: 12, avg: 177.33, max: 500)
#
# Run: 283, exploration: 0.0816735354288723, score: 422
# Scores: (min: 12, avg: 180.8, max: 500)
#
# Run: 284, exploration: 0.08059441550613461, score: 134
# Scores: (min: 12, avg: 180.79, max: 500)
#
# Run: 285, exploration: 0.07985631046714445, score: 93
# Scores: (min: 12, avg: 181.48, max: 500)
#
# Run: 286, exploration: 0.07796248118179314, score: 241
# Scores: (min: 12, avg: 182.11, max: 500)
#
# Run: 287, exploration: 0.07604509011868395, score: 250
# Scores: (min: 16, avg: 184.49, max: 500)
#
# Run: 288, exploration: 0.07310702660055161, score: 395
# Scores: (min: 16, avg: 186.92, max: 500)
#
# Run: 289, exploration: 0.07281516800732714, score: 41
# Scores: (min: 16, avg: 184.3, max: 500)
#
# Run: 290, exploration: 0.07164500766793974, score: 163
# Scores: (min: 16, avg: 185.44, max: 500)
#
# Run: 291, exploration: 0.06998089667190936, score: 236
# Scores: (min: 16, avg: 185.93, max: 500)
#
# Run: 292, exploration: 0.06979219367927113, score: 28
# Scores: (min: 16, avg: 184.74, max: 500)
#
# Run: 293, exploration: 0.06862255838117509, score: 170
# Scores: (min: 16, avg: 185.86, max: 500)
#
# Run: 294, exploration: 0.06729731534456528, score: 196
# Scores: (min: 16, avg: 187.54, max: 500)
#
# Run: 295, exploration: 0.06613641315145201, score: 175
# Scores: (min: 16, avg: 188.77, max: 500)
#
# Run: 296, exploration: 0.06365752640809381, score: 383
# Scores: (min: 16, avg: 191.66, max: 500)
#
# Run: 297, exploration: 0.06260948190369564, score: 167
# Scores: (min: 16, avg: 192.8, max: 500)
#
# Run: 298, exploration: 0.06155406440741684, score: 171
# Scores: (min: 16, avg: 194.25, max: 500)
#
# Run: 299, exploration: 0.0600402181161781, score: 250
# Scores: (min: 16, avg: 194.97, max: 500)
#
# Run: 300, exploration: 0.0581841551565407, score: 315
# Scores: (min: 16, avg: 196.6, max: 500)
#
# Solved in 200 runs, 300 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-984257b13a8a> in <module>
#      87             dqn_solver.experience_replay()
#      88
# ---> 89 cartpole()
#
# <ipython-input-5-984257b13a8a> in cartpole()
#      83             if terminal:
#      84                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 85                 score_logger.add_score(step, run)
#      86                 break
#      87             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
# modifying learning rate
# original = 0.001
# experiment = 0.0001
# solved in 329 total runs.

ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.0001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

cartpole()
# Out:
# Run: 1, exploration: 0.9000874278732445, score: 41
# Scores: (min: 41, avg: 41, max: 41)
#
# Run: 2, exploration: 0.8475428503023453, score: 13
# Scores: (min: 13, avg: 27, max: 41)
#
# Run: 3, exploration: 0.6596532430440636, score: 51
# Scores: (min: 13, avg: 35, max: 51)
#
# Run: 4, exploration: 0.6027415843082742, score: 19
# Scores: (min: 13, avg: 31, max: 51)
#
# Run: 5, exploration: 0.5535075230322891, score: 18
# Scores: (min: 13, avg: 28.4, max: 51)
#
# Run: 6, exploration: 0.500708706245853, score: 21
# Scores: (min: 13, avg: 27.166666666666668, max: 51)
#
# Run: 7, exploration: 0.4738479773082268, score: 12
# Scores: (min: 12, avg: 25, max: 51)
#
# Run: 8, exploration: 0.43080185560799106, score: 20
# Scores: (min: 12, avg: 24.375, max: 51)
#
# Run: 9, exploration: 0.41386834584198684, score: 9
# Scores: (min: 9, avg: 22.666666666666668, max: 51)
#
# Run: 10, exploration: 0.39166620452737816, score: 12
# Scores: (min: 9, avg: 21.6, max: 51)
#
# Run: 11, exploration: 0.3596735257153405, score: 18
# Scores: (min: 9, avg: 21.272727272727273, max: 51)
#
# Run: 12, exploration: 0.3455358541129786, score: 9
# Scores: (min: 9, avg: 20.25, max: 51)
#
# Run: 13, exploration: 0.32864265128599696, score: 11
# Scores: (min: 9, avg: 19.53846153846154, max: 51)
#
# Run: 14, exploration: 0.3125753549412418, score: 11
# Scores: (min: 9, avg: 18.928571428571427, max: 51)
#
# Run: 15, exploration: 0.30028896908517405, score: 9
# Scores: (min: 9, avg: 18.266666666666666, max: 51)
#
# Run: 16, exploration: 0.28704309604425327, score: 10
# Scores: (min: 9, avg: 17.75, max: 51)
#
# Run: 17, exploration: 0.2757603055760701, score: 9
# Scores: (min: 9, avg: 17.235294117647058, max: 51)
#
# Run: 18, exploration: 0.2494556624678441, score: 21
# Scores: (min: 9, avg: 17.444444444444443, max: 51)
#
# Run: 19, exploration: 0.23965031961336, score: 9
# Scores: (min: 9, avg: 17, max: 51)
#
# Run: 20, exploration: 0.23023039494318503, score: 9
# Scores: (min: 9, avg: 16.6, max: 51)
#
# Run: 21, exploration: 0.2211807388415433, score: 9
# Scores: (min: 9, avg: 16.238095238095237, max: 51)
#
# Run: 22, exploration: 0.21142436319205632, score: 10
# Scores: (min: 9, avg: 15.954545454545455, max: 51)
#
# Run: 23, exploration: 0.20209834538617025, score: 10
# Scores: (min: 9, avg: 15.695652173913043, max: 51)
#
# Run: 24, exploration: 0.1912566947289212, score: 12
# Scores: (min: 9, avg: 15.541666666666666, max: 51)
#
# Run: 25, exploration: 0.1800916657318127, score: 13
# Scores: (min: 9, avg: 15.44, max: 51)
#
# Run: 26, exploration: 0.16291280823111093, score: 21
# Scores: (min: 9, avg: 15.653846153846153, max: 51)
#
# Run: 27, exploration: 0.10376060541355137, score: 91
# Scores: (min: 9, avg: 18.444444444444443, max: 91)
#
# Run: 28, exploration: 0.0609928681304848, score: 107
# Scores: (min: 9, avg: 21.607142857142858, max: 107)
#
# Run: 29, exploration: 0.056575091797066025, score: 16
# Scores: (min: 9, avg: 21.413793103448278, max: 107)
#
# Run: 30, exploration: 0.05354009722551939, score: 12
# Scores: (min: 9, avg: 21.1, max: 107)
#
# Run: 31, exploration: 0.04966213277390804, score: 16
# Scores: (min: 9, avg: 20.93548387096774, max: 107)
#
# Run: 32, exploration: 0.046065053286412784, score: 16
# Scores: (min: 9, avg: 20.78125, max: 107)
#
# Run: 33, exploration: 0.04359387414694703, score: 12
# Scores: (min: 9, avg: 20.515151515151516, max: 107)
#
# Run: 34, exploration: 0.04146257532741124, score: 11
# Scores: (min: 9, avg: 20.235294117647058, max: 107)
#
# Run: 35, exploration: 0.03963364364733769, score: 10
# Scores: (min: 9, avg: 19.942857142857143, max: 107)
#
# Run: 36, exploration: 0.0378853869148274, score: 10
# Scores: (min: 9, avg: 19.666666666666668, max: 107)
#
# Run: 37, exploration: 0.03621424652392737, score: 10
# Scores: (min: 9, avg: 19.405405405405407, max: 107)
#
# Run: 38, exploration: 0.03461682084029365, score: 10
# Scores: (min: 9, avg: 19.157894736842106, max: 107)
#
# Run: 39, exploration: 0.03308985827710748, score: 10
# Scores: (min: 9, avg: 18.923076923076923, max: 107)
#
# Run: 40, exploration: 0.03178919665971424, score: 9
# Scores: (min: 9, avg: 18.675, max: 107)
#
# Run: 41, exploration: 0.030539660091838977, score: 9
# Scores: (min: 9, avg: 18.4390243902439, max: 107)
#
# Run: 42, exploration: 0.029339239003388088, score: 9
# Scores: (min: 9, avg: 18.214285714285715, max: 107)
#
# Run: 43, exploration: 0.02832764101944931, score: 8
# Scores: (min: 8, avg: 17.976744186046513, max: 107)
#
# Run: 44, exploration: 0.027350922279685573, score: 8
# Scores: (min: 8, avg: 17.75, max: 107)
#
# Run: 45, exploration: 0.026144461565619025, score: 10
# Scores: (min: 8, avg: 17.57777777777778, max: 107)
#
# Run: 46, exploration: 0.024991218342344988, score: 10
# Scores: (min: 8, avg: 17.41304347826087, max: 107)
#
# Run: 47, exploration: 0.024008889611965685, score: 9
# Scores: (min: 8, avg: 17.23404255319149, max: 107)
#
# Run: 48, exploration: 0.023065173234186005, score: 9
# Scores: (min: 8, avg: 17.0625, max: 107)
#
# Run: 49, exploration: 0.022047758717570132, score: 10
# Scores: (min: 8, avg: 16.918367346938776, max: 107)
#
# Run: 50, exploration: 0.020969846670345987, score: 11
# Scores: (min: 8, avg: 16.8, max: 107)
#
# Run: 51, exploration: 0.019944633602480003, score: 11
# Scores: (min: 8, avg: 16.686274509803923, max: 107)
#
# Run: 52, exploration: 0.018969543067746772, score: 11
# Scores: (min: 8, avg: 16.576923076923077, max: 107)
#
# Run: 53, exploration: 0.017951913959130504, score: 12
# Scores: (min: 8, avg: 16.49056603773585, max: 107)
#
# Run: 54, exploration: 0.017160047465104442, score: 10
# Scores: (min: 8, avg: 16.37037037037037, max: 107)
#
# Run: 55, exploration: 0.0164031105360144, score: 10
# Scores: (min: 8, avg: 16.254545454545454, max: 107)
#
# Run: 56, exploration: 0.015601164601953134, score: 11
# Scores: (min: 8, avg: 16.160714285714285, max: 107)
#
# Run: 57, exploration: 0.014838425699981627, score: 11
# Scores: (min: 8, avg: 16.07017543859649, max: 107)
#
# Run: 58, exploration: 0.014042412118399107, score: 12
# Scores: (min: 8, avg: 16, max: 107)
#
# Run: 59, exploration: 0.013156542237201536, score: 14
# Scores: (min: 8, avg: 15.966101694915254, max: 107)
#
# Run: 60, exploration: 0.012264924940880204, score: 15
# Scores: (min: 8, avg: 15.95, max: 107)
#
# Run: 61, exploration: 0.011319680961146208, score: 17
# Scores: (min: 8, avg: 15.967213114754099, max: 107)
#
# Run: 62, exploration: 0.01029135882494263, score: 20
# Scores: (min: 8, avg: 16.032258064516128, max: 107)
#
# Run: 63, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.03174603174603, max: 107)
#
# Run: 64, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.96875, max: 107)
#
# Run: 65, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.984615384615385, max: 107)
#
# Run: 66, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16, max: 107)
#
# Run: 67, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 16.029850746268657, max: 107)
#
# Run: 68, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.014705882352942, max: 107)
#
# Run: 69, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16, max: 107)
#
# Run: 70, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.971428571428572, max: 107)
#
# Run: 71, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.943661971830986, max: 107)
#
# Run: 72, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.88888888888889, max: 107)
#
# Run: 73, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.849315068493151, max: 107)
#
# Run: 74, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.81081081081081, max: 107)
#
# Run: 75, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 15.733333333333333, max: 107)
#
# Run: 76, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.671052631578947, max: 107)
#
# Run: 77, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.623376623376624, max: 107)
#
# Run: 78, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.576923076923077, max: 107)
#
# Run: 79, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.518987341772151, max: 107)
#
# Run: 80, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.475, max: 107)
#
# Run: 81, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.444444444444445, max: 107)
#
# Run: 82, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.414634146341463, max: 107)
#
# Run: 83, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.397590361445783, max: 107)
#
# Run: 84, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.380952380952381, max: 107)
#
# Run: 85, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 15.376470588235295, max: 107)
#
# Run: 86, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.337209302325581, max: 107)
#
# Run: 87, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 15.471264367816092, max: 107)
#
# Run: 88, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 15.579545454545455, max: 107)
#
# Run: 89, exploration: 0.01, score: 71
# Scores: (min: 8, avg: 16.202247191011235, max: 107)
#
# Run: 90, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 16.22222222222222, max: 107)
#
# Run: 91, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.23076923076923, max: 107)
#
# Run: 92, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.23913043478261, max: 107)
#
# Run: 93, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.182795698924732, max: 107)
#
# Run: 94, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.180851063829788, max: 107)
#
# Run: 95, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 16.126315789473683, max: 107)
#
# Run: 96, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.104166666666668, max: 107)
#
# Run: 97, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.082474226804123, max: 107)
#
# Run: 98, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.091836734693878, max: 107)
#
# Run: 99, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.07070707070707, max: 107)
#
# Run: 100, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.07, max: 107)
#
# Run: 101, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 15.84, max: 107)
#
# Run: 102, exploration: 0.01, score: 66
# Scores: (min: 8, avg: 16.37, max: 107)
#
# Run: 103, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.02, max: 107)
#
# Run: 104, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 15.95, max: 107)
#
# Run: 105, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.9, max: 107)
#
# Run: 106, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.83, max: 107)
#
# Run: 107, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 15.85, max: 107)
#
# Run: 108, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 15.81, max: 107)
#
# Run: 109, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.85, max: 107)
#
# Run: 110, exploration: 0.01, score: 20
# Scores: (min: 8, avg: 15.93, max: 107)
#
# Run: 111, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.88, max: 107)
#
# Run: 112, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.96, max: 107)
#
# Run: 113, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 15.98, max: 107)
#
# Run: 114, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.01, max: 107)
#
# Run: 115, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 16.05, max: 107)
#
# Run: 116, exploration: 0.01, score: 19
# Scores: (min: 8, avg: 16.14, max: 107)
#
# Run: 117, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 16.23, max: 107)
#
# Run: 118, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 16.15, max: 107)
#
# Run: 119, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 16.23, max: 107)
#
# Run: 120, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.29, max: 107)
#
# Run: 121, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 16.44, max: 107)
#
# Run: 122, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.49, max: 107)
#
# Run: 123, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 16.55, max: 107)
#
# Run: 124, exploration: 0.01, score: 13
# Scores: (min: 8, avg: 16.56, max: 107)
#
# Run: 125, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 16.58, max: 107)
#
# Run: 126, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 16.51, max: 107)
#
# Run: 127, exploration: 0.01, score: 17
# Scores: (min: 8, avg: 15.77, max: 107)
#
# Run: 128, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.82, max: 71)
#
# Run: 129, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.8, max: 71)
#
# Run: 130, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 14.8, max: 71)
#
# Run: 131, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.78, max: 71)
#
# Run: 132, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 14.77, max: 71)
#
# Run: 133, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 14.79, max: 71)
#
# Run: 134, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.79, max: 71)
#
# Run: 135, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 14.8, max: 71)
#
# Run: 136, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 14.86, max: 71)
#
# Run: 137, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 14.92, max: 71)
#
# Run: 138, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 14.98, max: 71)
#
# Run: 139, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 15.13, max: 71)
#
# Run: 140, exploration: 0.01, score: 59
# Scores: (min: 8, avg: 15.63, max: 71)
#
# Run: 141, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 15.77, max: 71)
#
# Run: 142, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 15.92, max: 71)
#
# Run: 143, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 16.02, max: 71)
#
# Run: 144, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 16.12, max: 71)
#
# Run: 145, exploration: 0.01, score: 18
# Scores: (min: 9, avg: 16.2, max: 71)
#
# Run: 146, exploration: 0.01, score: 19
# Scores: (min: 9, avg: 16.29, max: 71)
#
# Run: 147, exploration: 0.01, score: 17
# Scores: (min: 9, avg: 16.37, max: 71)
#
# Run: 148, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 16.48, max: 71)
#
# Run: 149, exploration: 0.01, score: 15
# Scores: (min: 10, avg: 16.53, max: 71)
#
# Run: 150, exploration: 0.01, score: 29
# Scores: (min: 10, avg: 16.71, max: 71)
#
# Run: 151, exploration: 0.01, score: 47
# Scores: (min: 10, avg: 17.07, max: 71)
#
# Run: 152, exploration: 0.01, score: 56
# Scores: (min: 10, avg: 17.52, max: 71)
#
# Run: 153, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 17.61, max: 71)
#
# Run: 154, exploration: 0.01, score: 46
# Scores: (min: 10, avg: 17.97, max: 71)
#
# Run: 155, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 18.1, max: 71)
#
# Run: 156, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 18.2, max: 71)
#
# Run: 157, exploration: 0.01, score: 42
# Scores: (min: 10, avg: 18.51, max: 71)
#
# Run: 158, exploration: 0.01, score: 24
# Scores: (min: 10, avg: 18.63, max: 71)
#
# Run: 159, exploration: 0.01, score: 21
# Scores: (min: 10, avg: 18.7, max: 71)
#
# Run: 160, exploration: 0.01, score: 27
# Scores: (min: 10, avg: 18.82, max: 71)
#
# Run: 161, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 18.87, max: 71)
#
# Run: 162, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 18.87, max: 71)
#
# Run: 163, exploration: 0.01, score: 62
# Scores: (min: 10, avg: 19.33, max: 71)
#
# Run: 164, exploration: 0.01, score: 67
# Scores: (min: 10, avg: 19.88, max: 71)
#
# Run: 165, exploration: 0.01, score: 51
# Scores: (min: 10, avg: 20.22, max: 71)
#
# Run: 166, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 20.27, max: 71)
#
# Run: 167, exploration: 0.01, score: 23
# Scores: (min: 10, avg: 20.32, max: 71)
#
# Run: 168, exploration: 0.01, score: 20
# Scores: (min: 10, avg: 20.37, max: 71)
#
# Run: 169, exploration: 0.01, score: 42
# Scores: (min: 10, avg: 20.64, max: 71)
#
# Run: 170, exploration: 0.01, score: 22
# Scores: (min: 10, avg: 20.72, max: 71)
#
# Run: 171, exploration: 0.01, score: 25
# Scores: (min: 10, avg: 20.83, max: 71)
#
# Run: 172, exploration: 0.01, score: 39
# Scores: (min: 10, avg: 21.1, max: 71)
#
# Run: 173, exploration: 0.01, score: 41
# Scores: (min: 10, avg: 21.38, max: 71)
#
# Run: 174, exploration: 0.01, score: 41
# Scores: (min: 10, avg: 21.66, max: 71)
#
# Run: 175, exploration: 0.01, score: 59
# Scores: (min: 11, avg: 22.15, max: 71)
#
# Run: 176, exploration: 0.01, score: 57
# Scores: (min: 11, avg: 22.61, max: 71)
#
# Run: 177, exploration: 0.01, score: 68
# Scores: (min: 11, avg: 23.17, max: 71)
#
# Run: 178, exploration: 0.01, score: 27
# Scores: (min: 11, avg: 23.32, max: 71)
#
# Run: 179, exploration: 0.01, score: 53
# Scores: (min: 11, avg: 23.74, max: 71)
#
# Run: 180, exploration: 0.01, score: 37
# Scores: (min: 11, avg: 23.99, max: 71)
#
# Run: 181, exploration: 0.01, score: 34
# Scores: (min: 11, avg: 24.2, max: 71)
#
# Run: 182, exploration: 0.01, score: 51
# Scores: (min: 11, avg: 24.58, max: 71)
#
# Run: 183, exploration: 0.01, score: 19
# Scores: (min: 11, avg: 24.63, max: 71)
#
# Run: 184, exploration: 0.01, score: 44
# Scores: (min: 11, avg: 24.93, max: 71)
#
# Run: 185, exploration: 0.01, score: 26
# Scores: (min: 11, avg: 25.04, max: 71)
#
# Run: 186, exploration: 0.01, score: 17
# Scores: (min: 11, avg: 25.09, max: 71)
#
# Run: 187, exploration: 0.01, score: 14
# Scores: (min: 11, avg: 24.96, max: 71)
#
# Run: 188, exploration: 0.01, score: 21
# Scores: (min: 11, avg: 24.92, max: 71)
#
# Run: 189, exploration: 0.01, score: 17
# Scores: (min: 11, avg: 24.38, max: 68)
#
# Run: 190, exploration: 0.01, score: 16
# Scores: (min: 11, avg: 24.36, max: 68)
#
# Run: 191, exploration: 0.01, score: 33
# Scores: (min: 11, avg: 24.52, max: 68)
#
# Run: 192, exploration: 0.01, score: 46
# Scores: (min: 11, avg: 24.81, max: 68)
#
# Run: 193, exploration: 0.01, score: 27
# Scores: (min: 11, avg: 24.97, max: 68)
#
# Run: 194, exploration: 0.01, score: 34
# Scores: (min: 11, avg: 25.15, max: 68)
#
# Run: 195, exploration: 0.01, score: 60
# Scores: (min: 11, avg: 25.64, max: 68)
#
# Run: 196, exploration: 0.01, score: 36
# Scores: (min: 11, avg: 25.86, max: 68)
#
# Run: 197, exploration: 0.01, score: 18
# Scores: (min: 11, avg: 25.9, max: 68)
#
# Run: 198, exploration: 0.01, score: 23
# Scores: (min: 11, avg: 25.96, max: 68)
#
# Run: 199, exploration: 0.01, score: 60
# Scores: (min: 11, avg: 26.42, max: 68)
#
# Run: 200, exploration: 0.01, score: 97
# Scores: (min: 11, avg: 27.23, max: 97)
#
# Run: 201, exploration: 0.01, score: 25
# Scores: (min: 11, avg: 27.3, max: 97)
#
# Run: 202, exploration: 0.01, score: 43
# Scores: (min: 11, avg: 27.07, max: 97)
#
# Run: 203, exploration: 0.01, score: 21
# Scores: (min: 11, avg: 27.12, max: 97)
#
# Run: 204, exploration: 0.01, score: 38
# Scores: (min: 11, avg: 27.38, max: 97)
#
# Run: 205, exploration: 0.01, score: 27
# Scores: (min: 11, avg: 27.52, max: 97)
#
# Run: 206, exploration: 0.01, score: 41
# Scores: (min: 11, avg: 27.79, max: 97)
#
# Run: 207, exploration: 0.01, score: 20
# Scores: (min: 11, avg: 27.85, max: 97)
#
# Run: 208, exploration: 0.01, score: 85
# Scores: (min: 11, avg: 28.54, max: 97)
#
# Run: 209, exploration: 0.01, score: 27
# Scores: (min: 11, avg: 28.68, max: 97)
#
# Run: 210, exploration: 0.01, score: 26
# Scores: (min: 11, avg: 28.74, max: 97)
#
# Run: 211, exploration: 0.01, score: 29
# Scores: (min: 11, avg: 28.9, max: 97)
#
# Run: 212, exploration: 0.01, score: 55
# Scores: (min: 11, avg: 29.28, max: 97)
#
# Run: 213, exploration: 0.01, score: 62
# Scores: (min: 11, avg: 29.77, max: 97)
#
# Run: 214, exploration: 0.01, score: 57
# Scores: (min: 11, avg: 30.2, max: 97)
#
# Run: 215, exploration: 0.01, score: 172
# Scores: (min: 11, avg: 31.79, max: 172)
#
# Run: 216, exploration: 0.01, score: 113
# Scores: (min: 11, avg: 32.73, max: 172)
#
# Run: 217, exploration: 0.01, score: 111
# Scores: (min: 11, avg: 33.66, max: 172)
#
# Run: 218, exploration: 0.01, score: 125
# Scores: (min: 11, avg: 34.78, max: 172)
#
# Run: 219, exploration: 0.01, score: 80
# Scores: (min: 11, avg: 35.41, max: 172)
#
# Run: 220, exploration: 0.01, score: 103
# Scores: (min: 11, avg: 36.29, max: 172)
#
# Run: 221, exploration: 0.01, score: 50
# Scores: (min: 11, avg: 36.55, max: 172)
#
# Run: 222, exploration: 0.01, score: 94
# Scores: (min: 11, avg: 37.34, max: 172)
#
# Run: 223, exploration: 0.01, score: 84
# Scores: (min: 11, avg: 38.02, max: 172)
#
# Run: 224, exploration: 0.01, score: 114
# Scores: (min: 11, avg: 39.03, max: 172)
#
# Run: 225, exploration: 0.01, score: 97
# Scores: (min: 11, avg: 39.85, max: 172)
#
# Run: 226, exploration: 0.01, score: 114
# Scores: (min: 11, avg: 40.85, max: 172)
#
# Run: 227, exploration: 0.01, score: 128
# Scores: (min: 11, avg: 41.96, max: 172)
#
# Run: 228, exploration: 0.01, score: 193
# Scores: (min: 11, avg: 43.77, max: 193)
#
# Run: 229, exploration: 0.01, score: 78
# Scores: (min: 11, avg: 44.41, max: 193)
#
# Run: 230, exploration: 0.01, score: 75
# Scores: (min: 11, avg: 45.04, max: 193)
#
# Run: 231, exploration: 0.01, score: 85
# Scores: (min: 11, avg: 45.75, max: 193)
#
# Run: 232, exploration: 0.01, score: 73
# Scores: (min: 11, avg: 46.33, max: 193)
#
# Run: 233, exploration: 0.01, score: 91
# Scores: (min: 11, avg: 47.1, max: 193)
#
# Run: 234, exploration: 0.01, score: 120
# Scores: (min: 11, avg: 48.19, max: 193)
#
# Run: 235, exploration: 0.01, score: 105
# Scores: (min: 14, avg: 49.13, max: 193)
#
# Run: 236, exploration: 0.01, score: 157
# Scores: (min: 14, avg: 50.54, max: 193)
#
# Run: 237, exploration: 0.01, score: 374
# Scores: (min: 14, avg: 54.12, max: 374)
#
# Run: 238, exploration: 0.01, score: 105
# Scores: (min: 14, avg: 55.01, max: 374)
#
# Run: 239, exploration: 0.01, score: 97
# Scores: (min: 14, avg: 55.73, max: 374)
#
# Run: 240, exploration: 0.01, score: 140
# Scores: (min: 14, avg: 56.54, max: 374)
#
# Run: 241, exploration: 0.01, score: 120
# Scores: (min: 14, avg: 57.51, max: 374)
#
# Run: 242, exploration: 0.01, score: 192
# Scores: (min: 14, avg: 59.19, max: 374)
#
# Run: 243, exploration: 0.01, score: 131
# Scores: (min: 14, avg: 60.32, max: 374)
#
# Run: 244, exploration: 0.01, score: 131
# Scores: (min: 14, avg: 61.45, max: 374)
#
# Run: 245, exploration: 0.01, score: 233
# Scores: (min: 14, avg: 63.6, max: 374)
#
# Run: 246, exploration: 0.01, score: 173
# Scores: (min: 14, avg: 65.14, max: 374)
#
# Run: 247, exploration: 0.01, score: 139
# Scores: (min: 14, avg: 66.36, max: 374)
#
# Run: 248, exploration: 0.01, score: 129
# Scores: (min: 14, avg: 67.45, max: 374)
#
# Run: 249, exploration: 0.01, score: 149
# Scores: (min: 14, avg: 68.79, max: 374)
#
# Run: 250, exploration: 0.01, score: 169
# Scores: (min: 14, avg: 70.19, max: 374)
#
# Run: 251, exploration: 0.01, score: 165
# Scores: (min: 14, avg: 71.37, max: 374)
#
# Run: 252, exploration: 0.01, score: 182
# Scores: (min: 14, avg: 72.63, max: 374)
#
# Run: 253, exploration: 0.01, score: 265
# Scores: (min: 14, avg: 75.07, max: 374)
#
# Run: 254, exploration: 0.01, score: 137
# Scores: (min: 14, avg: 75.98, max: 374)
#
# Run: 255, exploration: 0.01, score: 159
# Scores: (min: 14, avg: 77.34, max: 374)
#
# Run: 256, exploration: 0.01, score: 132
# Scores: (min: 14, avg: 78.45, max: 374)
#
# Run: 257, exploration: 0.01, score: 191
# Scores: (min: 14, avg: 79.94, max: 374)
#
# Run: 258, exploration: 0.01, score: 213
# Scores: (min: 14, avg: 81.83, max: 374)
#
# Run: 259, exploration: 0.01, score: 225
# Scores: (min: 14, avg: 83.87, max: 374)
#
# Run: 260, exploration: 0.01, score: 148
# Scores: (min: 14, avg: 85.08, max: 374)
#
# Run: 261, exploration: 0.01, score: 125
# Scores: (min: 14, avg: 86.11, max: 374)
#
# Run: 262, exploration: 0.01, score: 169
# Scores: (min: 14, avg: 87.6, max: 374)
#
# Run: 263, exploration: 0.01, score: 269
# Scores: (min: 14, avg: 89.67, max: 374)
#
# Run: 264, exploration: 0.01, score: 152
# Scores: (min: 14, avg: 90.52, max: 374)
#
# Run: 265, exploration: 0.01, score: 232
# Scores: (min: 14, avg: 92.33, max: 374)
#
# Run: 266, exploration: 0.01, score: 168
# Scores: (min: 14, avg: 93.79, max: 374)
#
# Run: 267, exploration: 0.01, score: 144
# Scores: (min: 14, avg: 95, max: 374)
#
# Run: 268, exploration: 0.01, score: 333
# Scores: (min: 14, avg: 98.13, max: 374)
#
# Run: 269, exploration: 0.01, score: 390
# Scores: (min: 14, avg: 101.61, max: 390)
#
# Run: 270, exploration: 0.01, score: 324
# Scores: (min: 14, avg: 104.63, max: 390)
#
# Run: 271, exploration: 0.01, score: 184
# Scores: (min: 14, avg: 106.22, max: 390)
#
# Run: 272, exploration: 0.01, score: 186
# Scores: (min: 14, avg: 107.69, max: 390)
#
# Run: 273, exploration: 0.01, score: 175
# Scores: (min: 14, avg: 109.03, max: 390)
#
# Run: 274, exploration: 0.01, score: 137
# Scores: (min: 14, avg: 109.99, max: 390)
#
# Run: 275, exploration: 0.01, score: 185
# Scores: (min: 14, avg: 111.25, max: 390)
#
# Run: 276, exploration: 0.01, score: 179
# Scores: (min: 14, avg: 112.47, max: 390)
#
# Run: 277, exploration: 0.01, score: 321
# Scores: (min: 14, avg: 115, max: 390)
#
# Run: 278, exploration: 0.01, score: 194
# Scores: (min: 14, avg: 116.67, max: 390)
#
# Run: 279, exploration: 0.01, score: 200
# Scores: (min: 14, avg: 118.14, max: 390)
#
# Run: 280, exploration: 0.01, score: 210
# Scores: (min: 14, avg: 119.87, max: 390)
#
# Run: 281, exploration: 0.01, score: 228
# Scores: (min: 14, avg: 121.81, max: 390)
#
# Run: 282, exploration: 0.01, score: 244
# Scores: (min: 14, avg: 123.74, max: 390)
#
# Run: 283, exploration: 0.01, score: 192
# Scores: (min: 14, avg: 125.47, max: 390)
#
# Run: 284, exploration: 0.01, score: 144
# Scores: (min: 14, avg: 126.47, max: 390)
#
# Run: 285, exploration: 0.01, score: 203
# Scores: (min: 14, avg: 128.24, max: 390)
#
# Run: 286, exploration: 0.01, score: 278
# Scores: (min: 14, avg: 130.85, max: 390)
#
# Run: 287, exploration: 0.01, score: 164
# Scores: (min: 16, avg: 132.35, max: 390)
#
# Run: 288, exploration: 0.01, score: 228
# Scores: (min: 16, avg: 134.42, max: 390)
#
# Run: 289, exploration: 0.01, score: 278
# Scores: (min: 16, avg: 137.03, max: 390)
#
# Run: 290, exploration: 0.01, score: 179
# Scores: (min: 18, avg: 138.66, max: 390)
#
# Run: 291, exploration: 0.01, score: 180
# Scores: (min: 18, avg: 140.13, max: 390)
#
# Run: 292, exploration: 0.01, score: 188
# Scores: (min: 18, avg: 141.55, max: 390)
#
# Run: 293, exploration: 0.01, score: 236
# Scores: (min: 18, avg: 143.64, max: 390)
#
# Run: 294, exploration: 0.01, score: 191
# Scores: (min: 18, avg: 145.21, max: 390)
#
# Run: 295, exploration: 0.01, score: 323
# Scores: (min: 18, avg: 147.84, max: 390)
#
# Run: 296, exploration: 0.01, score: 202
# Scores: (min: 18, avg: 149.5, max: 390)
#
# Run: 297, exploration: 0.01, score: 240
# Scores: (min: 20, avg: 151.72, max: 390)
#
# Run: 298, exploration: 0.01, score: 181
# Scores: (min: 20, avg: 153.3, max: 390)
#
# Run: 299, exploration: 0.01, score: 200
# Scores: (min: 20, avg: 154.7, max: 390)
#
# Run: 300, exploration: 0.01, score: 182
# Scores: (min: 20, avg: 155.55, max: 390)
#
# Run: 301, exploration: 0.01, score: 180
# Scores: (min: 20, avg: 157.1, max: 390)
#
# Run: 302, exploration: 0.01, score: 164
# Scores: (min: 20, avg: 158.31, max: 390)
#
# Run: 303, exploration: 0.01, score: 163
# Scores: (min: 20, avg: 159.73, max: 390)
#
# Run: 304, exploration: 0.01, score: 182
# Scores: (min: 20, avg: 161.17, max: 390)
#
# Run: 305, exploration: 0.01, score: 240
# Scores: (min: 20, avg: 163.3, max: 390)
#
# Run: 306, exploration: 0.01, score: 196
# Scores: (min: 20, avg: 164.85, max: 390)
#
# Run: 307, exploration: 0.01, score: 208
# Scores: (min: 26, avg: 166.73, max: 390)
#
# Run: 308, exploration: 0.01, score: 228
# Scores: (min: 26, avg: 168.16, max: 390)
#
# Run: 309, exploration: 0.01, score: 202
# Scores: (min: 26, avg: 169.91, max: 390)
#
# Run: 310, exploration: 0.01, score: 225
# Scores: (min: 29, avg: 171.9, max: 390)
#
# Run: 311, exploration: 0.01, score: 216
# Scores: (min: 50, avg: 173.77, max: 390)
#
# Run: 312, exploration: 0.01, score: 228
# Scores: (min: 50, avg: 175.5, max: 390)
#
# Run: 313, exploration: 0.01, score: 224
# Scores: (min: 50, avg: 177.12, max: 390)
#
# Run: 314, exploration: 0.01, score: 183
# Scores: (min: 50, avg: 178.38, max: 390)
#
# Run: 315, exploration: 0.01, score: 203
# Scores: (min: 50, avg: 178.69, max: 390)
#
# Run: 316, exploration: 0.01, score: 164
# Scores: (min: 50, avg: 179.2, max: 390)
#
# Run: 317, exploration: 0.01, score: 275
# Scores: (min: 50, avg: 180.84, max: 390)
#
# Run: 318, exploration: 0.01, score: 178
# Scores: (min: 50, avg: 181.37, max: 390)
#
# Run: 319, exploration: 0.01, score: 177
# Scores: (min: 50, avg: 182.34, max: 390)
#
# Run: 320, exploration: 0.01, score: 249
# Scores: (min: 50, avg: 183.8, max: 390)
#
# Run: 321, exploration: 0.01, score: 391
# Scores: (min: 73, avg: 187.21, max: 391)
#
# Run: 322, exploration: 0.01, score: 182
# Scores: (min: 73, avg: 188.09, max: 391)
#
# Run: 323, exploration: 0.01, score: 302
# Scores: (min: 73, avg: 190.27, max: 391)
#
# Run: 324, exploration: 0.01, score: 203
# Scores: (min: 73, avg: 191.16, max: 391)
#
# Run: 325, exploration: 0.01, score: 238
# Scores: (min: 73, avg: 192.57, max: 391)
#
# Run: 326, exploration: 0.01, score: 209
# Scores: (min: 73, avg: 193.52, max: 391)
#
# Run: 327, exploration: 0.01, score: 181
# Scores: (min: 73, avg: 194.05, max: 391)
#
# Run: 328, exploration: 0.01, score: 195
# Scores: (min: 73, avg: 194.07, max: 391)
#
# Run: 329, exploration: 0.01, score: 224
# Scores: (min: 73, avg: 195.53, max: 391)
#
# Solved in 229 runs, 329 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-47accb9125e7> in <module>
#      81             dqn_solver.experience_replay()
#      82
# ---> 83 cartpole()
#
# <ipython-input-6-47accb9125e7> in cartpole()
#      77             if terminal:
#      78                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 79                 score_logger.add_score(step, run)
#      80                 break
#      81             dqn_solver.experience_replay()
#
# U:\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Summary of experiements:
#
# Original Run:
# Solved after 152 total runs.
#
# Experiment One:
# Modified Discount Factor to 0.75
# Stopped test at 1500 total runs with no solution.
#
# Experiment Two:
# Modified Exploration Factor.
# Changed Min to 0.05
# Changed Decay to 0.9999
# Solved after 300 total runs.
#
# Experiment Three:
# Modified Learning Rate to 0.0001
# Solved after 329 total runs.
#
# Explain how reinforcement learning concepts apply to the cartpole problem.
# What is the goal of the agent in this case?
#     To keep the cartpole balanced by applying appropriate forces to a pivot point.
# What are the various state values?
#     Cart Position, Cart Velocity, Pole Angle, Pole Velocity At Tip
# What are the possible actions that can be performed?
#     Push cart to the left, Push cart to the right
# What reinforcement algorithm is used for this problem?
#     Deep Q-Learning
#
# Analyze how experience replay is applied to the cartpole problem.
# How does experience replay work in this algorithm?
#     It is a process that uniformly samples experiences from the memory and for each entry updates its Q value (Surma, 2019).
# What is the effect of introducing a discount factor for calculating the future rewards?
#     It makes an infinite sum finite.  If rewards are not discounted, the sum of the rewards would grow infinitely and an
#     optimal solution would not be found (Beysolow, 2019).
#
# Analyze how neural networks are used in deep Q-learning.
# Explain the neural network architecture that is used in the cartpole problem.
#     The neural network consists of an input layer, hidden layers, and an ouput layer.  The input comes from the observation
#     space then they are fed through the layers until the output layer selects and action.  The state if the environment is fed
#     into the neural network and the expected reward is calculated for each action.  The next action is then selected based on
#     the greatest possible reward (Kedia, 2020).  Q-Learning uses two neural networks in its learning process (Singh, 2022).
# How does the neural network make the Q-learning algorithm more efficient?
#     By remembering each state, and the possible rewards, actions are more efficiently selected.  "Despite having the same
#     architecture, these networks differ in their weights. During each N-step, the weights get copied between the main and
#     target networks. Both networks help the algorithm learn more effectively and stabilize the learning process" (Singh, 2022).
# What difference do you see in the algorithm performance when you increase or decrease the learning rate?
#     When decreasing the learning rate, it took much longer to solve the problem.
#
#
# References:
# Surma, G. (2019, November 10). Cartpole - introduction to reinforcement learning (DQN - deep Q-learning). Medium. Retrieved March 29, 2023, from https://gsurma.medium.com/cartpole-introduction-to-reinforcement-learning-ed0eb5b58288
#
# Gulli, A., & Pal, S. (2017). Deep learning with keras : Get to grips with the basics of keras to implement fast and efficient deep-learning models. Packt Publishing, Limited.
#
# Beysolow, I. T. (2019). Applied reinforcement learning with python : With openai gym, tensorflow, and keras. Apress L. P..
#
# Kedia, A. (2020, April 15). Creating deep neural networks from scratch, an introduction to reinforcement learning. Medium. Retrieved March 29, 2023, from https://towardsdatascience.com/creating-deep-neural-networks-from-scratch-an-introduction-to-reinforcement-learning-part-i-549ef7b149d2
#
# Singh, S. (2022, October 7). A comprehensive guide to neural networks in Deep Q-Learning. A Comprehensive Guide to Neural Networks in Deep Q-learning. Retrieved March 29, 2023, from https://www.turing.com/kb/how-are-neural-networks-used-in-deep-q-learning#how-deep-q-networks-function

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.
